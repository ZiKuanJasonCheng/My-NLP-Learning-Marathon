# %%
# !python --version
# Out:
# Python 3.7.3

# %%
#!pip install -q -U pip
#!pip install -q numpy
#!pip install -q pandas
#!pip install -q ckiptagger
#!pip install -q tqdm
#!pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets
# Out:
# WARNING: You are using pip version 20.2.2; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/jasoncheng/py3venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm
# Out:
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/jasoncheng/py3venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}
print(train_titles[0])
print(train_classes[0])

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}
print(test_titles[1800])
print(test_classes[1800])
# Out:
# 亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 體育
# 如果騎士火箭進入總決賽，誰的勝算大？
# 體育

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')

# %%
sentence_list = ["亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列", "9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜"]

word_sentence_list = ws(
        sentence_list,
        # sentence_segmentation = True, # To consider delimiters
        # segment_delimiter_set = {",", "。", ":", "?", "!", ";"}), # This is the defualt set of delimiters
        # recommend_dictionary = dictionary1, # words in this dictionary are encouraged
        # coerce_dictionary = dictionary2, # words in this dictionary are forced
)
print(word_sentence_list)

pos_sentence_list = pos(word_sentence_list)
print(pos_sentence_list)
# Out:
# [['亞洲杯', '奪', '冠賠率', '：', '日本', '、', '伊朗', '領銜', ' ', '中國', '竟', '與', '泰國', '並列'], ['9', '輪', '4', '球', '本土', '射手', '僅次', '武磊', ' ', '黃紫昌', '要', '搶', '最', '強', 'U23', '頭銜']]
# [['Nb', 'VC', 'Na', 'COLONCATEGORY', 'Nc', 'PAUSECATEGORY', 'Nc', 'VB', 'WHITESPACE', 'Nc', 'D', 'P', 'Nc', 'VG'], ['Neu', 'Nf', 'Neu', 'Na', 'Nc', 'Na', 'VJ', 'Nb', 'WHITESPACE', 'Nb', 'D', 'VD', 'Dfa', 'VH', 'Nb', 'Na']]

# %%
# train_title_cuts = {}
# for index, title in tqdm(train_titles.items()):
#     # YOUR CODE HERE
    
#     # END YOUR CODE
#     train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Keep the following result
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws(
        [title],
        # sentence_segmentation = True, # To consider delimiters
        # segment_delimiter_set = {",", "。", ":", "?", "!", ";"}), # This is the defualt set of delimiters
        # recommend_dictionary = dictionary1, # words in this dictionary are encouraged
        # coerce_dictionary = dictionary2, # words in this dictionary are forced
    )
    word_p = pos(word_s)
    
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)

    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
i = 0
for _, title_cuts in train_title_cuts.items():
    for word, pos in title_cuts:
        if word2index.get(word) is None:
            word2index[word] = i
            index2word[i] = word
            i += 1

for _, title_cuts in test_title_cuts.items():
    for word, pos in title_cuts:
        if word2index.get(word) is None:
            word2index[word] = i
            index2word[i] = word
            i += 1

# END YOUR CODE
print(len(word2index))
print(len(index2word))
# Out:
# 7958
# 7958

# %%
word2index
# Out:
# {'亞洲杯': 0,
#  '奪': 1,
#  '冠賠率': 2,
#  '：': 3,
#  '日本': 4,
#  '、': 5,
#  '伊朗': 6,
#  '領銜': 7,
#  ' ': 8,
#  '中國': 9,
#  '竟': 10,
#  '與': 11,
#  '泰國': 12,
#  '並列': 13,
#  '9': 14,
#  '輪': 15,
#  '4': 16,
#  '球': 17,
#  '本土': 18,
#  '射手': 19,
#  '僅次': 20,
#  '武磊': 21,
#  '黃紫昌': 22,
#  '要': 23,
#  '搶': 24,
#  '最': 25,
#  '強': 26,
#  'U23': 27,
#  '頭銜': 28,
#  '如果': 29,
#  '今年': 30,
#  '勇士': 31,
#  '奪冠': 32,
#  '，': 33,
#  '下': 34,
#  '賽': 35,
#  '季': 36,
#  '詹姆斯': 37,
#  '何去何從': 38,
#  '？': 39,
#  '超級': 40,
#  '替補': 41,
#  '！': 42,
#  '科斯塔': 43,
#  '本': 44,
#  '賽季': 45,
#  '出場': 46,
#  '貢獻': 47,
#  '7': 48,
#  '次': 49,
#  '助攻': 50,
#  '騎士': 51,
#  '6': 52,
#  '天里': 53,
#  '發生': 54,
#  '了': 55,
#  '啥': 56,
#  '從': 57,
#  '首': 58,
#  '七': 59,
#  '到': 60,
#  '次輪': 61,
#  '3-0': 62,
#  '猛龍': 63,
#  '朗多': 64,
#  '進入': 65,
#  '轉會': 66,
#  '市場': 67,
#  '哪些': 68,
#  '球隊': 69,
#  '適合': 70,
#  '他': 71,
#  'G3': 72,
#  '決殺': 73,
#  '你': 74,
#  '怎麼': 75,
#  '看': 76,
#  '大': 77,
#  '魔王': 78,
#  '帶頭': 79,
#  '唱歌': 80,
#  '火箭': 81,
#  '這': 82,
#  '像是': 83,
#  '打': 84,
#  '季後賽': 85,
#  '爵士': 86,
#  '神帥': 87,
#  '話': 88,
#  '已': 89,
#  '提前': 90,
#  '投降': 91,
#  '馬夏爾': 92,
#  '去': 93,
#  '切爾西': 94,
#  '可以': 95,
#  '商量': 96,
#  '不過': 97,
#  '穆里尼奧': 98,
#  '的': 99,
#  '要價': 100,
#  '是': 101,
#  '4000萬': 102,
#  '加威廉': 103,
#  '利希': 104,
#  '施泰納': 105,
#  '宣佈': 106,
#  '結束': 107,
#  '後': 108,
#  '離隊': 109,
#  '我': 110,
#  '需要': 111,
#  '新': 112,
#  '挑戰': 113,
#  '怎麼樣': 114,
#  '看待': 115,
#  '大連': 116,
#  '一方': 117,
#  '在': 118,
#  '中': 119,
#  '超聯賽': 120,
#  '第九': 121,
#  '取得': 122,
#  '勝': 123,
#  '科勒·卡戴珊': 124,
#  '男友': 125,
#  'TT': 126,
#  '共進': 127,
#  '午餐': 128,
#  '曾': 129,
#  '懷孕': 130,
#  '期間': 131,
#  '偷腥': 132,
#  '渣男': 133,
#  '被': 134,
#  '原': 135,
#  '作為': 136,
#  '央視': 137,
#  '體育': 138,
#  '頻道': 139,
#  'CCTV5': 140,
#  '一': 141,
#  '週末': 142,
#  '就': 143,
#  '直播': 144,
#  '馬拉松': 145,
#  '2018': 146,
#  '個': 147,
#  '冠軍': 148,
#  '含金量': 149,
#  '有': 150,
#  '多': 151,
#  '昔日': 152,
#  '超': 153,
#  '金靴': 154,
#  '半': 155,
#  '場': 156,
#  '獨造': 157,
#  '虐爆': 158,
#  '遼足': 159,
#  '華夏': 160,
#  '送走': 161,
#  '後悔': 162,
#  '嗎': 163,
#  'NBA': 164,
#  '歷史': 165,
#  '排名': 166,
#  '前': 167,
#  '十': 168,
#  '都': 169,
#  '誰': 170,
#  '希望': 171,
#  '利物浦': 172,
#  '贏得': 173,
#  '歐冠': 174,
#  '巴薩': 175,
#  '主帥': 176,
#  '巴爾韋德': 177,
#  '回答': 178,
#  '耐人尋味': 179,
#  '絕殺': 180,
#  '38': 181,
#  '+7': 182,
#  '再': 183,
#  '創': 184,
#  '傳奇': 185,
#  '刻': 186,
#  '兩護法': 187,
#  '另類': 188,
#  '神跡': 189,
#  '更': 190,
#  '功不可': 191,
#  '沒': 192,
#  '再現': 193,
#  '今天': 194,
#  '老詹': 195,
#  '吹': 196,
#  '拜仁': 197,
#  '3': 198,
#  '比': 199,
#  '1': 200,
#  '逆轉': 201,
#  '科隆': 202,
#  'J': 203,
#  '羅現': 204,
#  '世界級': 205,
#  '做': 206,
#  '餅': 207,
#  '白送': 208,
#  '點球': 209,
#  '恆': 210,
#  '大都': 211,
#  '不': 212,
#  '卡納瓦羅': 213,
#  '笑容': 214,
#  '真': 215,
#  '有意思': 216,
#  '劉詩雯': 217,
#  '戴罪': 218,
#  '立功': 219,
#  '取勝': 220,
#  '平野': 221,
#  '美宇': 222,
#  '為': 223,
#  '女乒': 224,
#  '拿到': 225,
#  '世乒賽': 226,
#  '比賽': 227,
#  '天堂': 228,
#  '地獄': 229,
#  '近': 230,
#  '看看': 231,
#  '最後': 232,
#  '8': 233,
#  '秒': 234,
#  '知道': 235,
#  '魯能': 236,
#  '隊員': 237,
#  '身高': 238,
#  'WKG&M-1世界': 239,
#  '綜合': 240,
#  '格鬥賽': 241,
#  '明星': 242,
#  '見面': 243,
#  '會': 244,
#  '引爆': 245,
#  '鵬城': 246,
#  '如何': 247,
#  '第一': 248,
#  '詹黑皮爾斯': 249,
#  '公開': 250,
#  '贊美': 251,
#  '粵媒': 252,
#  '缺少': 253,
#  '外援': 254,
#  '恆大': 255,
#  '還是': 256,
#  '不行': 257,
#  '熱刺作死': 258,
#  '節奏': 259,
#  '連': 260,
#  '墊底隊': 261,
#  '輸': 262,
#  '歐冠席': 263,
#  '位懸': 264,
#  '德帥': 265,
#  '談': 266,
#  '面試': 267,
#  '布茲德里克': 268,
#  '出於': 269,
#  '自私': 270,
#  '原因': 271,
#  '讓': 272,
#  '開心': 273,
#  '雙刃劍': 274,
#  '山東': 275,
#  '高中鋒': 276,
#  '人': 277,
#  '又': 278,
#  '愛': 279,
#  '恨': 280,
#  '克洛普': 281,
#  '凱塔': 282,
#  '能': 283,
#  '迅速': 284,
#  '起到': 285,
#  '作用': 286,
#  '可能': 287,
#  '邀請': 288,
#  '基輔': 289,
#  '歐洲': 290,
#  '歐冠難': 291,
#  '聯賽': 292,
#  '難': 293,
#  '篇': 294,
#  '文章': 295,
#  '將': 296,
#  '告訴': 297,
#  '您': 298,
#  '答案': 299,
#  '斯諾克': 300,
#  '世錦賽': 301,
#  '決賽': 302,
#  '馬克': 303,
#  '-': 304,
#  '威廉姆斯': 305,
#  '17': 306,
#  '15': 307,
#  '霍金斯': 308,
#  '希金斯': 309,
#  '和': 310,
#  '脂肪肝': 311,
#  '怎樣': 312,
#  '快': 313,
#  '消失': 314,
#  '韋德': 315,
#  '句': 316,
#  'bad boy': 317,
#  '網友': 318,
#  '們': 319,
#  '炸': 320,
#  '個個': 321,
#  '段子手': 322,
#  '中國隊': 323,
#  '抽到': 324,
#  '上上': 325,
#  '簽': 326,
#  '為何': 327,
#  '里皮': 328,
#  '臉色': 329,
#  '仍然': 330,
#  '很': 331,
#  '凝重': 332,
#  '今日': 333,
#  '龍星戰': 334,
#  '及': 335,
#  '女子': 336,
#  '圍甲': 337,
#  ' + ': 338,
#  '星陣': 339,
#  '先': 340,
#  '連勝': 341,
#  '暗渡': 342,
#  '陳倉': 343,
#  '奪得': 344,
#  '總冠軍': 345,
#  '就算': 346,
#  '建立': 347,
#  '王朝': 348,
#  '橫掃': 349,
#  '東部': 350,
#  '事': 351,
#  '已經': 352,
#  '乾': 353,
#  '過': 354,
#  '直接': 355,
#  '把': 356,
#  '對手': 357,
#  '打到': 358,
#  '解體': 359,
#  '重建': 360,
#  '陸家嘴': 361,
#  '金融城': 362,
#  '足球': 363,
#  '昨天': 364,
#  '拉開': 365,
#  '帷幕': 366,
#  '之': 367,
#  '夜': 368,
#  '5': 369,
#  '重': 370,
#  '摔': 371,
#  '地': 372,
#  '心酸': 373,
#  '也': 374,
#  '值得': 375,
#  '哦': 376,
#  '第114': 377,
#  '世界': 378,
#  '乒乓球': 379,
#  '—': 380,
#  '王楚欽': 381,
#  '對': 382,
#  '加油': 383,
#  '朱婷': 384,
#  '女排': 385,
#  '受傷': 386,
#  '瓦基弗': 387,
#  '產生': 388,
#  '影響': 389,
#  '還': 390,
#  '能夠': 391,
#  '德國': 392,
#  '男乒': 393,
#  '3:2': 394,
#  '艱難': 395,
#  '戰勝': 396,
#  '韓國': 397,
#  '挺進': 398,
#  '會師': 399,
#  '國乒': 400,
#  '德': 401,
#  '乒乓': 402,
#  '大戰': 403,
#  '勝算': 404,
#  '現在': 405,
#  '絕殺球': 406,
#  '能力': 407,
#  '聯盟': 408,
#  '什麼': 409,
#  '水準': 410,
#  '淘汰': 411,
#  '保': 412,
#  '住': 413,
#  '曼薩諾': 414,
#  '保級': 415,
#  '戰釀': 416,
#  '慘案': 417,
#  '球迷': 418,
#  '怒吼': 419,
#  '下課': 420,
#  '曝限': 421,
#  '薪令': 422,
#  '夏窗': 423,
#  '出台': 424,
#  '重慶': 425,
#  '或': 426,
#  '成': 427,
#  '受害': 428,
#  '者': 429,
#  '58': 430,
#  '同': 431,
#  '城': 432,
#  '中甲': 433,
#  '卓爾': 434,
#  '惹不起': 435,
#  '他們': 436,
#  '數據': 437,
#  '冠絕': 438,
#  '瑞典': 439,
#  '女隊': 440,
#  '新聞': 441,
#  '發佈會': 442,
#  '上': 443,
#  '石川佳純': 444,
#  '充當': 445,
#  '翻譯': 446,
#  '男團': 447,
#  '完勝': 448,
#  '兩': 449,
#  '隊': 450,
#  '排兵': 451,
#  '布陣': 452,
#  '亮點': 453,
#  '失誤': 454,
#  '道義': 455,
#  '放': 456,
#  '兩旁': 457,
#  '利': 458,
#  '字': 459,
#  '擺': 460,
#  '中間': 461,
#  '屢': 462,
#  '戰': 463,
#  '敗': 464,
#  '走': 465,
#  '遠': 466,
#  '游': 467,
#  '那麼': 468,
#  '地位': 469,
#  '受': 470,
#  '機會': 471,
#  '進': 472,
#  '總決賽': 473,
#  '通過': 474,
#  '運動': 475,
#  '健身': 476,
#  '覺得': 477,
#  '改變': 478,
#  '上港': 479,
#  '主場': 480,
#  '1-2': 481,
#  '負於': 482,
#  '國安': 483,
#  '遭遇': 484,
#  '連敗': 485,
#  '到底': 486,
#  '哪': 487,
#  '法網': 488,
#  '衛冕': 489,
#  '馬德里': 490,
#  '出局': 491,
#  '前景': 492,
#  '蒙上': 493,
#  '陰影': 494,
#  '步行': 495,
#  '戰成': 496,
#  '搶七': 497,
#  '險勝': 498,
#  '而': 499,
#  '即將': 500,
#  '跟': 501,
#  '區別': 502,
#  '哪裡': 503,
#  '中超': 504,
#  '單場': 505,
#  '消息': 506,
#  '埃爾克森': 507,
#  '建功': 508,
#  '救主': 509,
#  '惠若琪': 510,
#  '問': 511,
#  '素顏': 512,
#  '美': 513,
#  '她': 514,
#  '機智': 515,
#  '郎平': 516,
#  '維亞利': 517,
#  '尤文': 518,
#  '不應該': 519,
#  '埃姆雷': 520,
#  '詹': 521,
#  '該': 522,
#  '選': 523,
#  '拉基蒂奇': 524,
#  '3:0': 525,
#  '足協杯': 526,
#  '方': 527,
#  '大敗': 528,
#  '19年': 529,
#  '國足': 530,
#  '所在': 531,
#  'C組': 532,
#  '算是': 533,
#  '安德森': 534,
#  '依舊': 535,
#  '犀利': 536,
#  '對比': 537,
#  '之後': 538,
#  '並': 539,
#  '沒有': 540,
#  '變化': 541,
#  '德安東尼': 542,
#  '盤': 543,
#  '棋': 544,
#  '勒布朗': 545,
#  '美國': 546,
#  '各': 547,
#  '媒體': 548,
#  '公認': 549,
#  '第二': 550,
#  '喬丹': 551,
#  '差距': 552,
#  '究竟': 553,
#  '賽點': 554,
#  '此': 555,
#  '項': 556,
#  '超過': 557,
#  '凱西': 558,
#  '德羅贊': 559,
#  '投': 560,
#  '好': 561,
#  '其它': 562,
#  '比如': 563,
#  '防守': 564,
#  '24': 565,
#  '+': 566,
#  '+4': 567,
#  '新秀': 568,
#  '換人': 569,
#  '20': 570,
#  '歲': 571,
#  '天才': 572,
#  '刷爆': 573,
#  '72': 574,
#  '年': 575,
#  '小詹皇': 576,
#  '打爆': 577,
#  '逼': 578,
#  '平魯能': 579,
#  '京城': 580,
#  '狂漲粉': 581,
#  '北京': 582,
#  '下輪': 583,
#  '有望': 584,
#  '登頂': 585,
#  '銀行': 586,
#  '意大利': 587,
#  '晉級': 588,
#  '距離': 589,
#  '全滿貫': 590,
#  '步': 591,
#  '0:0': 592,
#  '戰平': 593,
#  '北京人和': 594,
#  '錯失': 595,
#  '良機': 596,
#  '評價': 597,
#  '為什麼': 598,
#  '提起': 599,
#  '火箭隊': 600,
#  '很多': 601,
#  '想起': 602,
#  '奧拉朱旺': 603,
#  '調侃': 604,
#  '自己': 605,
#  '職業': 606,
#  '生涯': 607,
#  '末端': 608,
#  '奧運會': 609,
#  '見到': 610,
#  '小棗': 611,
#  '2018年': 612,
#  '俄羅斯': 613,
#  '世界杯': 614,
#  '12': 615,
#  '座': 616,
#  '球館': 617,
#  '巡禮': 618,
#  '伏爾加格勒': 619,
#  '體育場': 620,
#  '詹皇': 621,
#  '樂福': 622,
#  '21': 623,
#  '16': 624,
#  '總': 625,
#  '分': 626,
#  '0': 627,
#  '斬落': 628,
#  '領頭': 629,
#  '羊': 630,
#  '攪亂': 631,
#  '超爭': 632,
#  '冠格局': 633,
#  '2019': 634,
#  '才': 635,
#  '「': 636,
#  '」': 637,
#  '水': 638,
#  '二': 639,
#  '浪': 640,
#  '三': 641,
#  '死神': 642,
#  '濃眉': 643,
#  '花迪': 644,
#  '葉': 645,
#  '橫批': 646,
#  '傑森': 647,
#  '特里': 648,
#  '塔特姆': 649,
#  '打出': 650,
#  '年齡': 651,
#  '極': 652,
#  '佳': 653,
#  '表現': 654,
#  '多點': 655,
#  '開花': 656,
#  '國際': 657,
#  '米蘭': 658,
#  '客場': 659,
#  '大勝': 660,
#  '烏迪內斯': 661,
#  '生猛': 662,
#  '女人': 663,
#  '當': 664,
#  '馬刺': 665,
#  '助教': 666,
#  '應聘': 667,
#  '主教練': 668,
#  '離': 669,
#  '不遠': 670,
#  '系列賽': 671,
#  '困擾': 672,
#  '解決': 673,
#  '優勢': 674,
#  '輕鬆': 675,
#  '破除': 676,
#  '四國': 677,
#  '青年': 678,
#  '女籃': 679,
#  '亞特拉斯賽': 680,
#  '秀': 681,
#  '舉行': 682,
#  '史蒂文斯': 683,
#  '神奇': 684,
#  '調整': 685,
#  '凱爾特': 686,
#  '加時': 687,
#  '76': 688,
#  '蘇群': 689,
#  '：76': 690,
#  '完': 691,
#  '大連海': 692,
#  '那麼多': 693,
#  '海': 694,
#  '遊樂': 695,
#  '項目': 696,
#  '連續': 697,
#  '13': 698,
#  '面對': 699,
#  '投進': 700,
#  '分組': 701,
#  '抽': 702,
#  '得': 703,
#  '一定': 704,
#  '出線': 705,
#  '撒': 706,
#  '彩紙': 707,
#  '看清楚': 708,
#  '打掃': 709,
#  '足足': 710,
#  '分鐘': 711,
#  '凱爾特人': 712,
#  '竊喜': 713,
#  '時間': 714,
#  '過去': 715,
#  '將近': 716,
#  '大家': 717,
#  '杜蘭特': 718,
#  '加盟': 719,
#  '件': 720,
#  '事情': 721,
#  '卡拉斯科': 722,
#  '底線': 723,
#  '過人': 724,
#  '本澤馬': 725,
#  '優秀': 726,
#  '用': 727,
#  '帶隊': 728,
#  '給': 729,
#  '現役': 730,
#  '球星': 731,
#  '五': 732,
#  '延邊': 733,
#  '富德': 734,
#  '樸泰夏': 735,
#  '米體': 736,
#  '比格利亞': 737,
#  '意大利杯': 738,
#  '復出': 739,
#  '九': 740,
#  '連冠': 741,
#  '郭躍': 742,
#  '社交': 743,
#  '平台': 744,
#  '說': 745,
#  '丁寧': 746,
#  '每': 747,
#  '輸掉': 748,
#  '猛': 749,
#  '龍主': 750,
#  '教練': 751,
#  '泰倫盧': 752,
#  '執教': 753,
#  '水平': 754,
#  '115': 755,
#  '隔扣': 756,
#  '犯規': 757,
#  '口': 758,
#  '出': 759,
#  '狂言': 760,
#  '聽': 761,
#  '巨星': 762,
#  '潛質': 763,
#  '你們': 764,
#  '李秋平': 765,
#  '山東隊': 766,
#  '可能性': 767,
#  '小組賽': 768,
#  '賽程': 769,
#  '出爐': 770,
#  '吉爾吉斯斯坦': 771,
#  'cba': 772,
#  '差': 773,
#  '小': 774,
#  '姚明': 775,
#  '奧運': 776,
#  '第四': 777,
#  '盼': 778,
#  '00': 779,
#  '運動員': 780,
#  '繼續': 781,
#  '國旗': 782,
#  '奮鬥': 783,
#  '科內利亞諾': 784,
#  '有沒有': 785,
#  '2:3': 786,
#  '不敵': 787,
#  '伊藤美誠': 788,
#  '看到': 789,
#  'VS': 790,
#  '鵜鶘': 791,
#  '稱': 792,
#  '放水': 793,
#  'WWE': 794,
#  '有錢': 795,
#  '約翰塞納': 796,
#  '私人': 797,
#  '車庫': 798,
#  '老闆': 799,
#  '車': 800,
#  '擊敗': 801,
#  '廣州': 802,
#  '勝利': 803,
#  '國人': 804,
#  '接受': 805,
#  '喜歡': 806,
#  '但': 807,
#  '張本智和': 808,
#  '日媒': 809,
#  '日乒': 810,
#  '正在': 811,
#  '縮小': 812,
#  '輸給': 813,
#  '後衛': 814,
#  '劉歡': 815,
#  '手球': 816,
#  '判罰': 817,
#  '誤判': 818,
#  '網傳': 819,
#  '《': 820,
#  '馬卡報': 821,
#  '》': 822,
#  '披露': 823,
#  '內馬爾': 824,
#  '皇馬': 825,
#  '搭檔': 826,
#  'C': 827,
#  '羅': 828,
#  '德甲': 829,
#  '官方': 830,
#  '第33': 831,
#  '最佳': 832,
#  '陣容': 833,
#  'J羅': 834,
#  '入選': 835,
#  '馬里奧': 836,
#  '戈麥斯': 837,
#  '列': 838,
#  '我們': 839,
#  '命懸': 840,
#  '一線': 841,
#  '武當': 842,
#  '掌門': 843,
#  '游玄德': 844,
#  '生活': 845,
#  '。': 846,
#  '街鬥': 847,
#  '對陣': 848,
#  '泰拳王西': 849,
#  '提猜': 850,
#  '結果': 851,
#  '慘敗': 852,
#  '因': 853,
#  '曝光': 854,
#  '錯誤': 855,
#  '上演': 856,
#  '鍋': 857,
#  '背': 858,
#  '-0': 859,
#  '客平人和': 860,
#  '國家': 861,
#  '新人': 862,
#  '試': 863,
#  '金石': 864,
#  '若': 865,
#  '把握住': 866,
#  '上位': 867,
#  '必': 868,
#  '大器': 869,
#  '率領': 870,
#  '來': 871,
#  '路': 872,
#  '變': 873,
#  '詹吹': 874,
#  '爵爺': 875,
#  '請': 876,
#  '贏': 877,
#  '負': 878,
#  '策略': 879,
#  '不當': 880,
#  '磨礪': 881,
#  '自我': 882,
#  '救贖': 883,
#  '劉國梁': 884,
#  '贊': 885,
#  '點': 886,
#  '壓哨': 887,
#  '拋投': 888,
#  '國腳': 889,
#  '張呈棟': 890,
#  '想': 891,
#  '書': 892,
#  '離開': 893,
#  '新疆': 894,
#  '如': 895,
#  '點贊': 896,
#  '引來': 897,
#  '馬競': 898,
#  '指責': 899,
#  '球王': 900,
#  '22': 901,
#  '新星': 902,
#  '戲耍': 903,
#  '國': 904,
#  '腳': 905,
#  '太': 906,
#  '強悍': 907,
#  '曼聯': 908,
#  '弗格森': 909,
#  '突發': 910,
#  '腦溢血': 911,
#  '入院': 912,
#  '情況': 913,
#  '侯森': 914,
#  '定位': 915,
#  '代班門': 916,
#  '等': 917,
#  '楊智': 918,
#  '國安會': 919,
#  '進一步': 920,
#  '易': 921,
#  '建聯': 922,
#  '接班人': 923,
#  '曬': 924,
#  '邀請函': 925,
#  ' 秀': 926,
#  '警句': 927,
#  '激勵': 928,
#  '不忘': 929,
#  '初心': 930,
#  '西蒙斯': 931,
#  '涼涼': 932,
#  '，0': 933,
#  '追': 934,
#  '吧': 935,
#  '丟': 936,
#  '女團': 937,
#  '值不值得': 938,
#  '表揚': 939,
#  '跑': 940,
#  '準備': 941,
#  '些': 942,
#  'CBA': 943,
#  '張': 944,
#  '圖': 945,
#  '一目瞭然': 946,
#  '內線': 947,
#  '強硬': 948,
#  '競籃': 949,
#  '2': 950,
#  '串': 951,
#  '擒': 952,
#  '騎': 953,
#  '士官': 954,
#  '宣一': 955,
#  '做出': 956,
#  '回應': 957,
#  '泰倫盧成': 958,
#  '贏家': 959,
#  '鐵': 960,
#  '主力': 961,
#  '無緣': 962,
#  '德比': 963,
#  '支': 964,
#  '踢': 965,
#  '狂': 966,
#  '14': 967,
#  '紀錄': 968,
#  '殘疾人': 969,
#  '射擊': 970,
#  '錦標賽': 971,
#  '河北': 972,
#  '姑娘': 973,
#  '破': 974,
#  '馬龍': 975,
#  '樊振東': 976,
#  '許昕': 977,
#  '上場': 978,
#  '奧恰洛夫': 979,
#  '無奈': 980,
#  '變陣': 981,
#  '自由': 982,
#  '搏擊': 983,
#  '傳統': 984,
#  '武術': 985,
#  '厲害': 986,
#  '這樣': 987,
#  '問題': 988,
#  '位': 989,
#  '球員': 990,
#  '2019年': 991,
#  '抽籤': 992,
#  '揭曉': 993,
#  '真的': 994,
#  '榜單': 995,
#  '只': 996,
#  '屈居': 997,
#  '得分榜': 998,
#  '無可': 999,
#  ...}

# %%
index2word
# Out:
# {0: '亞洲杯',
#  1: '奪',
#  2: '冠賠率',
#  3: '：',
#  4: '日本',
#  5: '、',
#  6: '伊朗',
#  7: '領銜',
#  8: ' ',
#  9: '中國',
#  10: '竟',
#  11: '與',
#  12: '泰國',
#  13: '並列',
#  14: '9',
#  15: '輪',
#  16: '4',
#  17: '球',
#  18: '本土',
#  19: '射手',
#  20: '僅次',
#  21: '武磊',
#  22: '黃紫昌',
#  23: '要',
#  24: '搶',
#  25: '最',
#  26: '強',
#  27: 'U23',
#  28: '頭銜',
#  29: '如果',
#  30: '今年',
#  31: '勇士',
#  32: '奪冠',
#  33: '，',
#  34: '下',
#  35: '賽',
#  36: '季',
#  37: '詹姆斯',
#  38: '何去何從',
#  39: '？',
#  40: '超級',
#  41: '替補',
#  42: '！',
#  43: '科斯塔',
#  44: '本',
#  45: '賽季',
#  46: '出場',
#  47: '貢獻',
#  48: '7',
#  49: '次',
#  50: '助攻',
#  51: '騎士',
#  52: '6',
#  53: '天里',
#  54: '發生',
#  55: '了',
#  56: '啥',
#  57: '從',
#  58: '首',
#  59: '七',
#  60: '到',
#  61: '次輪',
#  62: '3-0',
#  63: '猛龍',
#  64: '朗多',
#  65: '進入',
#  66: '轉會',
#  67: '市場',
#  68: '哪些',
#  69: '球隊',
#  70: '適合',
#  71: '他',
#  72: 'G3',
#  73: '決殺',
#  74: '你',
#  75: '怎麼',
#  76: '看',
#  77: '大',
#  78: '魔王',
#  79: '帶頭',
#  80: '唱歌',
#  81: '火箭',
#  82: '這',
#  83: '像是',
#  84: '打',
#  85: '季後賽',
#  86: '爵士',
#  87: '神帥',
#  88: '話',
#  89: '已',
#  90: '提前',
#  91: '投降',
#  92: '馬夏爾',
#  93: '去',
#  94: '切爾西',
#  95: '可以',
#  96: '商量',
#  97: '不過',
#  98: '穆里尼奧',
#  99: '的',
#  100: '要價',
#  101: '是',
#  102: '4000萬',
#  103: '加威廉',
#  104: '利希',
#  105: '施泰納',
#  106: '宣佈',
#  107: '結束',
#  108: '後',
#  109: '離隊',
#  110: '我',
#  111: '需要',
#  112: '新',
#  113: '挑戰',
#  114: '怎麼樣',
#  115: '看待',
#  116: '大連',
#  117: '一方',
#  118: '在',
#  119: '中',
#  120: '超聯賽',
#  121: '第九',
#  122: '取得',
#  123: '勝',
#  124: '科勒·卡戴珊',
#  125: '男友',
#  126: 'TT',
#  127: '共進',
#  128: '午餐',
#  129: '曾',
#  130: '懷孕',
#  131: '期間',
#  132: '偷腥',
#  133: '渣男',
#  134: '被',
#  135: '原',
#  136: '作為',
#  137: '央視',
#  138: '體育',
#  139: '頻道',
#  140: 'CCTV5',
#  141: '一',
#  142: '週末',
#  143: '就',
#  144: '直播',
#  145: '馬拉松',
#  146: '2018',
#  147: '個',
#  148: '冠軍',
#  149: '含金量',
#  150: '有',
#  151: '多',
#  152: '昔日',
#  153: '超',
#  154: '金靴',
#  155: '半',
#  156: '場',
#  157: '獨造',
#  158: '虐爆',
#  159: '遼足',
#  160: '華夏',
#  161: '送走',
#  162: '後悔',
#  163: '嗎',
#  164: 'NBA',
#  165: '歷史',
#  166: '排名',
#  167: '前',
#  168: '十',
#  169: '都',
#  170: '誰',
#  171: '希望',
#  172: '利物浦',
#  173: '贏得',
#  174: '歐冠',
#  175: '巴薩',
#  176: '主帥',
#  177: '巴爾韋德',
#  178: '回答',
#  179: '耐人尋味',
#  180: '絕殺',
#  181: '38',
#  182: '+7',
#  183: '再',
#  184: '創',
#  185: '傳奇',
#  186: '刻',
#  187: '兩護法',
#  188: '另類',
#  189: '神跡',
#  190: '更',
#  191: '功不可',
#  192: '沒',
#  193: '再現',
#  194: '今天',
#  195: '老詹',
#  196: '吹',
#  197: '拜仁',
#  198: '3',
#  199: '比',
#  200: '1',
#  201: '逆轉',
#  202: '科隆',
#  203: 'J',
#  204: '羅現',
#  205: '世界級',
#  206: '做',
#  207: '餅',
#  208: '白送',
#  209: '點球',
#  210: '恆',
#  211: '大都',
#  212: '不',
#  213: '卡納瓦羅',
#  214: '笑容',
#  215: '真',
#  216: '有意思',
#  217: '劉詩雯',
#  218: '戴罪',
#  219: '立功',
#  220: '取勝',
#  221: '平野',
#  222: '美宇',
#  223: '為',
#  224: '女乒',
#  225: '拿到',
#  226: '世乒賽',
#  227: '比賽',
#  228: '天堂',
#  229: '地獄',
#  230: '近',
#  231: '看看',
#  232: '最後',
#  233: '8',
#  234: '秒',
#  235: '知道',
#  236: '魯能',
#  237: '隊員',
#  238: '身高',
#  239: 'WKG&M-1世界',
#  240: '綜合',
#  241: '格鬥賽',
#  242: '明星',
#  243: '見面',
#  244: '會',
#  245: '引爆',
#  246: '鵬城',
#  247: '如何',
#  248: '第一',
#  249: '詹黑皮爾斯',
#  250: '公開',
#  251: '贊美',
#  252: '粵媒',
#  253: '缺少',
#  254: '外援',
#  255: '恆大',
#  256: '還是',
#  257: '不行',
#  258: '熱刺作死',
#  259: '節奏',
#  260: '連',
#  261: '墊底隊',
#  262: '輸',
#  263: '歐冠席',
#  264: '位懸',
#  265: '德帥',
#  266: '談',
#  267: '面試',
#  268: '布茲德里克',
#  269: '出於',
#  270: '自私',
#  271: '原因',
#  272: '讓',
#  273: '開心',
#  274: '雙刃劍',
#  275: '山東',
#  276: '高中鋒',
#  277: '人',
#  278: '又',
#  279: '愛',
#  280: '恨',
#  281: '克洛普',
#  282: '凱塔',
#  283: '能',
#  284: '迅速',
#  285: '起到',
#  286: '作用',
#  287: '可能',
#  288: '邀請',
#  289: '基輔',
#  290: '歐洲',
#  291: '歐冠難',
#  292: '聯賽',
#  293: '難',
#  294: '篇',
#  295: '文章',
#  296: '將',
#  297: '告訴',
#  298: '您',
#  299: '答案',
#  300: '斯諾克',
#  301: '世錦賽',
#  302: '決賽',
#  303: '馬克',
#  304: '-',
#  305: '威廉姆斯',
#  306: '17',
#  307: '15',
#  308: '霍金斯',
#  309: '希金斯',
#  310: '和',
#  311: '脂肪肝',
#  312: '怎樣',
#  313: '快',
#  314: '消失',
#  315: '韋德',
#  316: '句',
#  317: 'bad boy',
#  318: '網友',
#  319: '們',
#  320: '炸',
#  321: '個個',
#  322: '段子手',
#  323: '中國隊',
#  324: '抽到',
#  325: '上上',
#  326: '簽',
#  327: '為何',
#  328: '里皮',
#  329: '臉色',
#  330: '仍然',
#  331: '很',
#  332: '凝重',
#  333: '今日',
#  334: '龍星戰',
#  335: '及',
#  336: '女子',
#  337: '圍甲',
#  338: ' + ',
#  339: '星陣',
#  340: '先',
#  341: '連勝',
#  342: '暗渡',
#  343: '陳倉',
#  344: '奪得',
#  345: '總冠軍',
#  346: '就算',
#  347: '建立',
#  348: '王朝',
#  349: '橫掃',
#  350: '東部',
#  351: '事',
#  352: '已經',
#  353: '乾',
#  354: '過',
#  355: '直接',
#  356: '把',
#  357: '對手',
#  358: '打到',
#  359: '解體',
#  360: '重建',
#  361: '陸家嘴',
#  362: '金融城',
#  363: '足球',
#  364: '昨天',
#  365: '拉開',
#  366: '帷幕',
#  367: '之',
#  368: '夜',
#  369: '5',
#  370: '重',
#  371: '摔',
#  372: '地',
#  373: '心酸',
#  374: '也',
#  375: '值得',
#  376: '哦',
#  377: '第114',
#  378: '世界',
#  379: '乒乓球',
#  380: '—',
#  381: '王楚欽',
#  382: '對',
#  383: '加油',
#  384: '朱婷',
#  385: '女排',
#  386: '受傷',
#  387: '瓦基弗',
#  388: '產生',
#  389: '影響',
#  390: '還',
#  391: '能夠',
#  392: '德國',
#  393: '男乒',
#  394: '3:2',
#  395: '艱難',
#  396: '戰勝',
#  397: '韓國',
#  398: '挺進',
#  399: '會師',
#  400: '國乒',
#  401: '德',
#  402: '乒乓',
#  403: '大戰',
#  404: '勝算',
#  405: '現在',
#  406: '絕殺球',
#  407: '能力',
#  408: '聯盟',
#  409: '什麼',
#  410: '水準',
#  411: '淘汰',
#  412: '保',
#  413: '住',
#  414: '曼薩諾',
#  415: '保級',
#  416: '戰釀',
#  417: '慘案',
#  418: '球迷',
#  419: '怒吼',
#  420: '下課',
#  421: '曝限',
#  422: '薪令',
#  423: '夏窗',
#  424: '出台',
#  425: '重慶',
#  426: '或',
#  427: '成',
#  428: '受害',
#  429: '者',
#  430: '58',
#  431: '同',
#  432: '城',
#  433: '中甲',
#  434: '卓爾',
#  435: '惹不起',
#  436: '他們',
#  437: '數據',
#  438: '冠絕',
#  439: '瑞典',
#  440: '女隊',
#  441: '新聞',
#  442: '發佈會',
#  443: '上',
#  444: '石川佳純',
#  445: '充當',
#  446: '翻譯',
#  447: '男團',
#  448: '完勝',
#  449: '兩',
#  450: '隊',
#  451: '排兵',
#  452: '布陣',
#  453: '亮點',
#  454: '失誤',
#  455: '道義',
#  456: '放',
#  457: '兩旁',
#  458: '利',
#  459: '字',
#  460: '擺',
#  461: '中間',
#  462: '屢',
#  463: '戰',
#  464: '敗',
#  465: '走',
#  466: '遠',
#  467: '游',
#  468: '那麼',
#  469: '地位',
#  470: '受',
#  471: '機會',
#  472: '進',
#  473: '總決賽',
#  474: '通過',
#  475: '運動',
#  476: '健身',
#  477: '覺得',
#  478: '改變',
#  479: '上港',
#  480: '主場',
#  481: '1-2',
#  482: '負於',
#  483: '國安',
#  484: '遭遇',
#  485: '連敗',
#  486: '到底',
#  487: '哪',
#  488: '法網',
#  489: '衛冕',
#  490: '馬德里',
#  491: '出局',
#  492: '前景',
#  493: '蒙上',
#  494: '陰影',
#  495: '步行',
#  496: '戰成',
#  497: '搶七',
#  498: '險勝',
#  499: '而',
#  500: '即將',
#  501: '跟',
#  502: '區別',
#  503: '哪裡',
#  504: '中超',
#  505: '單場',
#  506: '消息',
#  507: '埃爾克森',
#  508: '建功',
#  509: '救主',
#  510: '惠若琪',
#  511: '問',
#  512: '素顏',
#  513: '美',
#  514: '她',
#  515: '機智',
#  516: '郎平',
#  517: '維亞利',
#  518: '尤文',
#  519: '不應該',
#  520: '埃姆雷',
#  521: '詹',
#  522: '該',
#  523: '選',
#  524: '拉基蒂奇',
#  525: '3:0',
#  526: '足協杯',
#  527: '方',
#  528: '大敗',
#  529: '19年',
#  530: '國足',
#  531: '所在',
#  532: 'C組',
#  533: '算是',
#  534: '安德森',
#  535: '依舊',
#  536: '犀利',
#  537: '對比',
#  538: '之後',
#  539: '並',
#  540: '沒有',
#  541: '變化',
#  542: '德安東尼',
#  543: '盤',
#  544: '棋',
#  545: '勒布朗',
#  546: '美國',
#  547: '各',
#  548: '媒體',
#  549: '公認',
#  550: '第二',
#  551: '喬丹',
#  552: '差距',
#  553: '究竟',
#  554: '賽點',
#  555: '此',
#  556: '項',
#  557: '超過',
#  558: '凱西',
#  559: '德羅贊',
#  560: '投',
#  561: '好',
#  562: '其它',
#  563: '比如',
#  564: '防守',
#  565: '24',
#  566: '+',
#  567: '+4',
#  568: '新秀',
#  569: '換人',
#  570: '20',
#  571: '歲',
#  572: '天才',
#  573: '刷爆',
#  574: '72',
#  575: '年',
#  576: '小詹皇',
#  577: '打爆',
#  578: '逼',
#  579: '平魯能',
#  580: '京城',
#  581: '狂漲粉',
#  582: '北京',
#  583: '下輪',
#  584: '有望',
#  585: '登頂',
#  586: '銀行',
#  587: '意大利',
#  588: '晉級',
#  589: '距離',
#  590: '全滿貫',
#  591: '步',
#  592: '0:0',
#  593: '戰平',
#  594: '北京人和',
#  595: '錯失',
#  596: '良機',
#  597: '評價',
#  598: '為什麼',
#  599: '提起',
#  600: '火箭隊',
#  601: '很多',
#  602: '想起',
#  603: '奧拉朱旺',
#  604: '調侃',
#  605: '自己',
#  606: '職業',
#  607: '生涯',
#  608: '末端',
#  609: '奧運會',
#  610: '見到',
#  611: '小棗',
#  612: '2018年',
#  613: '俄羅斯',
#  614: '世界杯',
#  615: '12',
#  616: '座',
#  617: '球館',
#  618: '巡禮',
#  619: '伏爾加格勒',
#  620: '體育場',
#  621: '詹皇',
#  622: '樂福',
#  623: '21',
#  624: '16',
#  625: '總',
#  626: '分',
#  627: '0',
#  628: '斬落',
#  629: '領頭',
#  630: '羊',
#  631: '攪亂',
#  632: '超爭',
#  633: '冠格局',
#  634: '2019',
#  635: '才',
#  636: '「',
#  637: '」',
#  638: '水',
#  639: '二',
#  640: '浪',
#  641: '三',
#  642: '死神',
#  643: '濃眉',
#  644: '花迪',
#  645: '葉',
#  646: '橫批',
#  647: '傑森',
#  648: '特里',
#  649: '塔特姆',
#  650: '打出',
#  651: '年齡',
#  652: '極',
#  653: '佳',
#  654: '表現',
#  655: '多點',
#  656: '開花',
#  657: '國際',
#  658: '米蘭',
#  659: '客場',
#  660: '大勝',
#  661: '烏迪內斯',
#  662: '生猛',
#  663: '女人',
#  664: '當',
#  665: '馬刺',
#  666: '助教',
#  667: '應聘',
#  668: '主教練',
#  669: '離',
#  670: '不遠',
#  671: '系列賽',
#  672: '困擾',
#  673: '解決',
#  674: '優勢',
#  675: '輕鬆',
#  676: '破除',
#  677: '四國',
#  678: '青年',
#  679: '女籃',
#  680: '亞特拉斯賽',
#  681: '秀',
#  682: '舉行',
#  683: '史蒂文斯',
#  684: '神奇',
#  685: '調整',
#  686: '凱爾特',
#  687: '加時',
#  688: '76',
#  689: '蘇群',
#  690: '：76',
#  691: '完',
#  692: '大連海',
#  693: '那麼多',
#  694: '海',
#  695: '遊樂',
#  696: '項目',
#  697: '連續',
#  698: '13',
#  699: '面對',
#  700: '投進',
#  701: '分組',
#  702: '抽',
#  703: '得',
#  704: '一定',
#  705: '出線',
#  706: '撒',
#  707: '彩紙',
#  708: '看清楚',
#  709: '打掃',
#  710: '足足',
#  711: '分鐘',
#  712: '凱爾特人',
#  713: '竊喜',
#  714: '時間',
#  715: '過去',
#  716: '將近',
#  717: '大家',
#  718: '杜蘭特',
#  719: '加盟',
#  720: '件',
#  721: '事情',
#  722: '卡拉斯科',
#  723: '底線',
#  724: '過人',
#  725: '本澤馬',
#  726: '優秀',
#  727: '用',
#  728: '帶隊',
#  729: '給',
#  730: '現役',
#  731: '球星',
#  732: '五',
#  733: '延邊',
#  734: '富德',
#  735: '樸泰夏',
#  736: '米體',
#  737: '比格利亞',
#  738: '意大利杯',
#  739: '復出',
#  740: '九',
#  741: '連冠',
#  742: '郭躍',
#  743: '社交',
#  744: '平台',
#  745: '說',
#  746: '丁寧',
#  747: '每',
#  748: '輸掉',
#  749: '猛',
#  750: '龍主',
#  751: '教練',
#  752: '泰倫盧',
#  753: '執教',
#  754: '水平',
#  755: '115',
#  756: '隔扣',
#  757: '犯規',
#  758: '口',
#  759: '出',
#  760: '狂言',
#  761: '聽',
#  762: '巨星',
#  763: '潛質',
#  764: '你們',
#  765: '李秋平',
#  766: '山東隊',
#  767: '可能性',
#  768: '小組賽',
#  769: '賽程',
#  770: '出爐',
#  771: '吉爾吉斯斯坦',
#  772: 'cba',
#  773: '差',
#  774: '小',
#  775: '姚明',
#  776: '奧運',
#  777: '第四',
#  778: '盼',
#  779: '00',
#  780: '運動員',
#  781: '繼續',
#  782: '國旗',
#  783: '奮鬥',
#  784: '科內利亞諾',
#  785: '有沒有',
#  786: '2:3',
#  787: '不敵',
#  788: '伊藤美誠',
#  789: '看到',
#  790: 'VS',
#  791: '鵜鶘',
#  792: '稱',
#  793: '放水',
#  794: 'WWE',
#  795: '有錢',
#  796: '約翰塞納',
#  797: '私人',
#  798: '車庫',
#  799: '老闆',
#  800: '車',
#  801: '擊敗',
#  802: '廣州',
#  803: '勝利',
#  804: '國人',
#  805: '接受',
#  806: '喜歡',
#  807: '但',
#  808: '張本智和',
#  809: '日媒',
#  810: '日乒',
#  811: '正在',
#  812: '縮小',
#  813: '輸給',
#  814: '後衛',
#  815: '劉歡',
#  816: '手球',
#  817: '判罰',
#  818: '誤判',
#  819: '網傳',
#  820: '《',
#  821: '馬卡報',
#  822: '》',
#  823: '披露',
#  824: '內馬爾',
#  825: '皇馬',
#  826: '搭檔',
#  827: 'C',
#  828: '羅',
#  829: '德甲',
#  830: '官方',
#  831: '第33',
#  832: '最佳',
#  833: '陣容',
#  834: 'J羅',
#  835: '入選',
#  836: '馬里奧',
#  837: '戈麥斯',
#  838: '列',
#  839: '我們',
#  840: '命懸',
#  841: '一線',
#  842: '武當',
#  843: '掌門',
#  844: '游玄德',
#  845: '生活',
#  846: '。',
#  847: '街鬥',
#  848: '對陣',
#  849: '泰拳王西',
#  850: '提猜',
#  851: '結果',
#  852: '慘敗',
#  853: '因',
#  854: '曝光',
#  855: '錯誤',
#  856: '上演',
#  857: '鍋',
#  858: '背',
#  859: '-0',
#  860: '客平人和',
#  861: '國家',
#  862: '新人',
#  863: '試',
#  864: '金石',
#  865: '若',
#  866: '把握住',
#  867: '上位',
#  868: '必',
#  869: '大器',
#  870: '率領',
#  871: '來',
#  872: '路',
#  873: '變',
#  874: '詹吹',
#  875: '爵爺',
#  876: '請',
#  877: '贏',
#  878: '負',
#  879: '策略',
#  880: '不當',
#  881: '磨礪',
#  882: '自我',
#  883: '救贖',
#  884: '劉國梁',
#  885: '贊',
#  886: '點',
#  887: '壓哨',
#  888: '拋投',
#  889: '國腳',
#  890: '張呈棟',
#  891: '想',
#  892: '書',
#  893: '離開',
#  894: '新疆',
#  895: '如',
#  896: '點贊',
#  897: '引來',
#  898: '馬競',
#  899: '指責',
#  900: '球王',
#  901: '22',
#  902: '新星',
#  903: '戲耍',
#  904: '國',
#  905: '腳',
#  906: '太',
#  907: '強悍',
#  908: '曼聯',
#  909: '弗格森',
#  910: '突發',
#  911: '腦溢血',
#  912: '入院',
#  913: '情況',
#  914: '侯森',
#  915: '定位',
#  916: '代班門',
#  917: '等',
#  918: '楊智',
#  919: '國安會',
#  920: '進一步',
#  921: '易',
#  922: '建聯',
#  923: '接班人',
#  924: '曬',
#  925: '邀請函',
#  926: ' 秀',
#  927: '警句',
#  928: '激勵',
#  929: '不忘',
#  930: '初心',
#  931: '西蒙斯',
#  932: '涼涼',
#  933: '，0',
#  934: '追',
#  935: '吧',
#  936: '丟',
#  937: '女團',
#  938: '值不值得',
#  939: '表揚',
#  940: '跑',
#  941: '準備',
#  942: '些',
#  943: 'CBA',
#  944: '張',
#  945: '圖',
#  946: '一目瞭然',
#  947: '內線',
#  948: '強硬',
#  949: '競籃',
#  950: '2',
#  951: '串',
#  952: '擒',
#  953: '騎',
#  954: '士官',
#  955: '宣一',
#  956: '做出',
#  957: '回應',
#  958: '泰倫盧成',
#  959: '贏家',
#  960: '鐵',
#  961: '主力',
#  962: '無緣',
#  963: '德比',
#  964: '支',
#  965: '踢',
#  966: '狂',
#  967: '14',
#  968: '紀錄',
#  969: '殘疾人',
#  970: '射擊',
#  971: '錦標賽',
#  972: '河北',
#  973: '姑娘',
#  974: '破',
#  975: '馬龍',
#  976: '樊振東',
#  977: '許昕',
#  978: '上場',
#  979: '奧恰洛夫',
#  980: '無奈',
#  981: '變陣',
#  982: '自由',
#  983: '搏擊',
#  984: '傳統',
#  985: '武術',
#  986: '厲害',
#  987: '這樣',
#  988: '問題',
#  989: '位',
#  990: '球員',
#  991: '2019年',
#  992: '抽籤',
#  993: '揭曉',
#  994: '真的',
#  995: '榜單',
#  996: '只',
#  997: '屈居',
#  998: '得分榜',
#  999: '無可',
#  ...}

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros((len(word2index)))
    for i, (word, pos) in enumerate(pairs):
        vector[word2index[word]] += 1
    
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['魅族', '梁建章', 'm15', '谷歌', '盼保', '德羅', '英特爾', '許', '庫里', '榮威', '索尼', '迪士尼', '后羿', '楊智', '安琪拉', '王楚欽', '切爾西', '雪迪龍', '郭懿', '寶二', '遼足', '呂布', '希金斯', '猛', '伯德', '韓長賦', '郭煒煒', '吉尼斯', '華為', '李白界', 'P60八核讓', '小強', '卡納瓦羅', '康德', '李白', '余小C', '凱西', '韓寒', '皇馬', '張藝謀', '微醫', '沃爾瑪', '泰山', 'V10', '盧克肖', 'G3，76', '卓爾', '卡拉黑', '姚明', '維特爾', '張掖篇', '湯米', '山東隊', '慧商', '霍金斯', '特里', '羅', '國四', '萊萬', '拉卡拉', '維韋杜詹霍', '李秋平', '富德', '魯能', '馬卡報', '切沃', '張良咸', '韋神', '阿里巴巴', 'G7', '奧拉朱旺', '哈希', '密子君', '阿里雲', '弗格森', '王者榮', '易', '北京人和', '施泰納', '朱之文', '綠心', '艷武漢', '勒布朗詹姆斯', '宇通', '張', '王昭君', '惠若琪', '董明珠', '詹姆斯', '奧尼爾', '東決', '穆里尼奧', '阿里舜宇', '阿木木歷', '·瞻', '羅永浩', '大美', '威少', '石川佳純', '安德森']
# =======================
# VC : ['實施', '爆發出', '寫', '大戰', '打服', '中', '大賺', '推介', '通', '吊打', '攔', '挖', '栽種', '破', '創造', '帶火', '攻略', '打野', '打擊', '收取', '承包', '冠絕', '摘', '抽到', '精選', '拍攝', '招', '包里', '割', '體驗', '死', '募', '攢', '解決', '隔扣', '踐行', '重建', '蒙上', '解說', '春栽', '食用', '趕', '種', '增收', '點贊', '閃', '唱起', '添脫', '縊縮', '賣出', '降', '聯繫', '記', '剪除', '賒', '絕殺', '領導', '存', '教會', '激勵', '引發', '列', '收割', '訓練', '保留', '找回', '取捨', '擺脫', '創', '害', '養殖', '打破', '邀請', '搞', '罵', '分銷', '接', '完虐', '辦', '打', '纏', '醫療', '推動', '削弱', '弄崩', '求', '兌付', '行', '扣除', '搭上', '提出', '托運', '招待', '數', '力爭', '碰到', '虧', '外掛', '約', '放棄']
# =======================
# Na : ['虧損', '金蛋蛋', '危機', '特攻式', '城市', '獅', '日媒', '全民健身', '衝超隊', '大器', '女籃', '大夢', '類目', '攻略', '意甲', '陰影', '月租', '小伙', '利潤', '視點', '股東', '名字', '堡壘', '生態環境', '狀態', '悅花', '特幣', '性', '招', '美國人', '實用性', '回答', '馬哈魚', '雙刃劍', '貧保', '品質', '運動會', '指南', '茄果類', '美團', '諾手', '球隊', '入圍賽', '實盤', '美', '鍋', '基本', '股神', '火鍋', '淘寶客', '經濟學家', '紅險', '面積', '奶爸', '穿梭機', '核心', '花兒', '農機', '機構', '鱸', '不鏽鋼', '歐冠', '墊腳', '嘲諷度', '卷葉', '總裁', '勝率', '閃電狼', '榮耀', '一體', '稻苗', '秸稈', '王朝', '紅米', '果農', '古會', '支票本', '拳頭', '春風', '藥', '蛋', '電視', '輩子', '程序員', '嚴寒期', '商人', '天價', '收穫', '碎片', '女', '病', '用工', '現象', '需求', '農村人', '機遇', '商機', '秘密', '須彌', '途徑']
# =======================
# COLONCATEGORY : ['：', ':']
# =======================
# Nc : ['崇義', '咸陽', '莊家', '東北', '城市', '中', '掌門', '安徽', '侗寨', '吉林', '休斯頓', '延邊', '聖堂山', '災房', '緬甸', '村', '香格里拉', '燴面店', '市場', '兩岸', '浦口', '後座', '雜貨鋪', '果園地', '興鄉村', '切爾西', '店', '優區', '南粵', '上川島', '黑龍江', '宅', '海外', '川藏', '貴州省', '華僑城', '美', '日照市', '萊加內斯', '潛江', '幻想鄉', '轄區', '洛陽', '劇情里', '信訪局', '體校', '房頂', '非洲', '商鋪', '，國', '達州', '賽場', '大理', '學校', '冠格局', '富縣', '萊茵河', '京城', '全球', '天下', '巴中市', '城鎮', '吐魯番', '沂水', '自治縣', '景區', '果園', '果嶺', '眼前', '鹽城', '巨蛋', '山西', '東城', '大洲島', '縣里', '易縣', '酒店', '長春', '華中區', '溫州', '意大利', '珠海市', '吉爾吉斯斯坦', '成都', '泰山', '龍江', '游景點', '孔子湖', '邊境縣', '西安', '三亞', '阿拉德', '鄭州', '年畫村', '火焰山', '工廠', '場', '茶鄉', '國', '鄉村']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['加油', '加工', '通話', '罵屌絲', '分組', '鍍金', '復仇', '代打', '鋪平', '一網打盡', '定位', '騙錢', '拍照', '開戰', '執教', '分紅', '護航', '導航', '解惑', '扣分', '收回來', '站台', '解體', '入賬', '加冕', '退貨', '助威', '充飢', '退款', '抓來', '提前', '計算出來', '加起來', '再見', '領銜', '效力', '應對', '解密', '加持', '退改', '罰款', '解圍', '分段', '充氣', '上架', '融資', '相比']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['交互', '依然', '老是', '驟然', '獨', '真的', '難以', '專職', '會不會', '凌空', '率先', '亂', '不可以', '就', '為什麼', '將', '不得不', '總會', '初', '還可以', '雙雙', '同', '也', '親身', '均', '沒有', '呼好', '一頭', '只有', '互相', '盡', '大幅', '只是', '不', '何以', '隨地', '來', '那麼', '未', '真', '重新', '及時', '全程', '偶爾', '永遠', '應', '紛紛', '互', '反', '可', '大都', '趕快', '其實', '一直', '逐漸', '一起', '這麼', '會', '不用', '已然', '能不能', '陸續', '實在', '一定', '一般', '親自', '可以', '如何', '到底', '應該', '大規模', '總算', '正在', '無可', '不可', '隨時', '卻', '相互', '大力', '該', '首', '快', '多多', '需', '總', '全面', '連', '預先', '不再', '再度', '竟然', '急劇', '一手', '一', '所', '進一步', '再次', '先', '竟', '真是']
# =======================
# P : ['比', '因', '往', '按', '隨', '除了', '臨', '離', '遭', '根據', '靠', '於', '與', '直至', '至', '繼', '就', '跟', '關於', '將', '和', '像', '把', '受', '憑', '比如', '趁著', '幫', '自', '向', '給', '除', '隨了', '等', '到', '用', '對', '為', '被', '以', '為了', '針對', '在', '如', '待', '距離', '趁', '慘遭', '自從', '從', '當']
# =======================
# VG : ['姓', '稱', '名叫', '成', '叫', '升任', '等於', '彷彿', '當成', '稱作', '稱得上', '戰成', '非', '排', '化', '賣成', '譽為', '像', '充當', '合成', '做成', '似', '並列', '叫做', '居', '評選', '竟是', '改造成', '建成', '變成', '疑似', '作為', '理解為', '形成', '稱為', '當作', '屬於', '應聘', '類似', '酷似', '排行', '算', '為', '屈居', '堪稱', '成為', '集成', '算是', '猶如', '封號', '如', '誤認成', '排名', '變', '投票成', '美成', '當上', '做', '當']
# =======================
# Neu : ['2:1', '50', '第1', '十多萬', '1900億', '98', '兩', '24', '300萬', '一萬', '60多', '第9', '第五', '九', '三十', '12', '4萬多', '24億', '711', '1699', '萬億', '2:3', '318', '幾百', '二十', '第十四', '54', '22', '7', '500萬', '25', '一百', '56', '1.8億', '23萬一', '5.6千三', '100', '1268', '835', '600', '3:0', '5.7', '（二）', '20億', '2萬', '10', '第一！', '八', '7300', '30萬', '十萬', '六', '1200億', '50萬', '百億', '5萬', '十五萬', '2018.5.6', '4G+64', '135', '七八千', '三百', '72', '8.7億', '200', '第七', '萬', '11億', '30000億', '十', '第二', '17', '15.60', '第三', '4.5', '第九', '980', '！2018', '70萬', '一', '7億', '5.6', '47', '第四', '42', '715', '2.93億', '13888', '千億', '20', '0:0', '兩四', '3:1', '60萬', '8', '48', '400萬', '46萬', '2.5', '115']
# =======================
# Nf : ['隻', '家', '盤', '輛', '斤', '局', '位', '年', '檔', '只', '袋', '招', '篇', '批', '棵', '條', '遍', '晚', '級', '種', '戶', '槍', '港元', '鍋', '套', '筆', '公里', '件', '秒', '屆', '路', '英吋', '頓', '所', '票', 'K', '米', '步', '回', '株', '行', '點', '名', '週', '掛', '頭', '度', '節', '美元', '些', '串', '類', '道', '把', '歲', '則', '頁', '碗', '刻', '支', '樣', '噸', '層', '句', '日', '項', '處', '號', '門', '場', '周', '座', '分鐘', '方', '口', '毛', '元', '天', '隊', '分', '本', '關', '塊', '股', '班', '張', '次', '期', '款', '色', '台', '對', '部', '群', '個', '輪', '畝', '胎', '片', '番']
# =======================
# VJ : ['晉級', '虧損', '翻倍', '符合', '連接', '獨佔', '領跑', '缺', '缺少', '脫', '僅次於', '曬', '受', '偏愛', '沒有', '含有', '維持', '負', '看懂', '失', '發揮', '抗', '曝限', '欣賞', '珍惜', '耗', '新增', '強過', '心疼', '認識', '毫無', '歸屬於', '擁有', '懷念', '蘊藏', '恪守', '靠', '分享', '超過', '來自', '僅次', '不如', '領略', '處於', '適應', '從事', '惜', '嫌棄', '輸掉', '不理', '替代', '過完', '看好', '持有', '忽視', '共有', '受到', '佔', '沈迷', '失去', '遭遇', '沒', '身臨', '喪失', '錯過', '不敵', '自有', '贏得', '得', '贏下', '近', '錯失', '出', '震撼到', '適用', '贊同', '平', '高達', '領先', '限', '冷落', '發生', '吸引', '展望', '羨慕', '超', '煥發', '充', '看不過去', '忽略', '負於', '大勝', '服', '無', '為', '同情', '遺傳', '逾', '熱心', '認']
# =======================
# VD : ['贏', '清繳', '予', '收費', '支付', '送', '供應', '拒賠', '售', '賣', '白送', '交付', '補貼', '輸給', '貸', '欠', '分', '借貸', '搶', '轉讓', '禁售', '給', '付', '坑', '借', '補繳', '貸款', '提供', '發', '輸', '傳', '發放', '郵給', '發給', '寄予', '還', '配', '給予', '速遞']
# =======================
# Dfa : ['越來越', '更', '較', '最', '過', '頗', '多', '非常', '如此', '還要', '更為', '很', '太', '遠遠', '比較', '同樣', '超', '過於', '十分', '有些', '好', '極', '還', '不大', '有點', '遠', '這麼']
# =======================
# VH : ['啓用', '忙', '出局', '下跌', '時髦', '再現', '頻繁', '激增', '咸', '實惠', '多姿', '有錢', '滿滿', '通車', '獨立', '可怕', '任重', '相對', '連敗', '低', '富', '漲停', '簡單', '死', '理想', '差', '爆紅', '當之無愧', '頭疼', '實用', '扎心', '平庸', '拔涼拔涼', '吃香', '不少', '無效', '屏穩', '純', '美', '熱刺托大', '自動', '活', '有毒', '簡約', '零零', '猛', '落單', '大敗', '保溫', '強硬', '堅', '色綠', '爛', '絕殺', '難得', '快', '疲軟', '靈活', '渾濁', '相生', '收場', '恍然大悟', '風光', '開心', '一樣', '眾包', '慎', '難', '不錯', '公平', '完勝', '上了年紀', '密集', '未果', '主動', '行', '多樣', '清貧', '像樣', '受害', '新', '現代', '史無前例', '假', '貧', '公正', '清幽', '窘', '奇怪', '穿', '機智', '病', '有用', '苦不堪言', '理智', '力輓狂瀾', '分布', '好看', '幸福', '沸騰']
# =======================
# Cbb : ['因', '但是', '若', '另外', '而', '還不如', '不過', '因為', '反而', '不如', '但', '既', '否則', '雖然', '連', '跟著', '不管', '只有', '只要', '不然', '並且', '假如', '縱使', '既然', '就算', '即使', '可是', '要是', '並', '而是', '不僅', '如果']
# =======================
# Nd : ['一日', '8月', '1點', '明', '夏季', '4月', '春', '2018年', '6月', '七月份', '如今', '幾月份', '7日', '首日', '30號', '今夏', '00年', '同時', '當年', '週二', '熱天', '5月份', '5號', '一會', '米節', '今天', '明晚', '19年', '12日', '狗年', '未來', '夏窗', '2017年', '長期', '雍正', '季', '多久', '春天', '週一', '今年', '23日', '文化節', '明年', '立夏', '旅遊節', '後', '六', '小時候', '晚清', '相親節', '旺季', '那時', '大中', '昨天', '以後', '夏日', '06日', '4日', '夏', '夜', '後期', '5日', '後來', '31號', '當前', '晚間', '五月份', '2018年度', '5.7日', '10點', '永久', '今日', '現代', '臨時', '當時', '2020年', '3月', '05月', '秋', '早晨', '短期', '隔年', '季度', '昔日', '春季', '13點', '下旬', '一大早', '現在', '6旬', '以前', '15年', '夏天', '90年', '明日', '四月', '目前', '7號', '晚上', '2035年']
# =======================
# VA : ['握手', '退票', '就業', '巡禮', '郊遊', '探秘', '摘帽', '創業', '投標', '報關', '轉農', '自駕', '怒吼', '醒', '睡', '養家糊口', '派息', '啓動', '算卦', '相約', '歸來', '變身', '打野刀', '點贊', '栽桑', '走', '養花', '相克', '放水', '絕殺', '偷鯤', '加密', '戴罪', '看過來', '餵尿素', '復盤', '點球', '墊腳', '釣魚', '晨跑', '字字珠璣', '現身', '續費', '脫貧', '造假', '面對面', '頂風', '徜徉', '行', '觀光', '除權', '拍案叫絕', '神杯', '看盤', '種地', '生財', '相親', '合伙', '投訴', '騎行', '毀號', '助攻', '消失', '發貨', '徵信', '投降', '游', '募資', '來臨', '出單', '休閒', '申遺', '跳', '扶貧', '爬山', '大笑', '產仔', '掃尾', '暴走', '紮營', '搭檔', '擾民', '加時', '開課', '建功', '成交', '出門', '點頭', '下降', '奮鬥', '探險', '打團', '抓頂', '上門', '育秧', '打卡', '划溝', '擺地攤', '哭', '收錢']
# =======================
# COMMACATEGORY : ['，', ',']
# =======================
# Nes : ['該', '頭', '首', '貴', '何', '某', '本', '前', '每', '後', '下', '各', '同', '近', '上', '另']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['著', '個', '起來', '了', '過']
# =======================
# Nep : ['其', '此', '其中', '這', '啥', '什麼', '哪', '那']
# =======================
# Caa : ['比', 'VS', '跟', '還是', '和', '或', '或者', '及', '又', '到', '暨', '與', '至', '或是']
# =======================
# VCL : ['走訪', '住', '往', '跌至', '前來', '路過', '升至', '過', '穿透', '盤踞', '跌出', '回到', '出發到', '出', '栽進', '深入', '退出', '進', '遊覽', '蒞臨', '進入', '橫掃', '遠離', '走過', '直達', '上', '穿過', '度過', '走進', '重回', '到', '存進', '登陸', '來到', '穿越', '暗渡', '入', '走下', '回', '重返', '用於', '前往', '在', '走到', '去', '抵達', '留在', '玩遍', '赴', '到達', '回歸']
# =======================
# Neqa : ['步步', '很多', '所有', '多', '12%', '個個', '30%', '不少', '9.89%', '這麼多', '41.8%', '20%', '那些', '這些', '滴滴', '全', '1%', '一點', '多點', '15%', '一些', '四成', '句句', '其它', '任何', '大多數', '1/4', '大多', '多少', '無數', '更多', '一切', '大量', '80%', '100%', '部分', '許多', '三分之一', '有些', '遍', '6%', '一處處', '有的', '0.8%', '10%', '其他', '67%', '一半', '8%', '半', '百分之八十', '90%', '哪些']
# =======================
# Nh : ['它', '俺們', '小眾', '一方', '別人', '自身', '他', '你們', '我們', '她們', '自我', '各位', '她', '他們', '父子倆', '它們', '你', '人家', '屌絲', '私人', '各自', '您', '我', '自己', '本人', '個人', '對方', '雙方', '誰', '大家']
# =======================
# FW : ['MARVEL X', 'ST', 'IOS', 'BCH', 'Disneyland', '2W', 'iBoy', 'G', ' vs 利物浦', 'DOTA2 ', 'Xbox ', ' MDL', '4AM', 'LPL', 'CCTV5', 'ADC', '4H', 'VS', 'CFPL', 'CEO', 'qq', 'app', 'A', 'Guru', 'SKU', ' 28', ' 利', ' + ', 'mix2', 'NPC', 'CF', '6G+', 'OTT', 'Kitty', 'shou', 'note5', 'IG', 'CCR', 'eStar', 'Lol里', 'Rank', 'Oeanc', 'LOL：MSI', 'iPad', 'AG', 'i7', 'DASH', 'dnf', 'Nvidia', 'VR ', 'max2', 'h', 'PVE', 'AWM', 'P2P', 'bad boy', 'GDP', 'Hello ', 'AI', 'Instagram', 'cpu', '！DOTA2 MOD', '：BTC', 'Aloha', 'NBA ', '<', 'N7', 'PGM 0-1 SUP', 'D', 'Credo', 'Khan', 'Ghappy', 'iPhone7', '/', 'MSI', 'Alan', ' 展', 'Minecraft', 'iphone6plus', 'IP', 'LOL：', 'APP', 'BTC', 'S11', 'ios', ' 樂', 'K', 'Uzi', 'HTC', 'PS', 'QDC', ' 比', 'Focus', 'FF ', 'vip', 'iPhone X', 'Kakao', 'RNG', 'eStarPro vs WF.D', 'OPPO R']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['稱', '說', '暗示', '做到', '探索', '感嘆', '防止', '判罰', '查找', '預告', '幻想', '回答', '算', '講', '聽到', '預期', '深思', '見證', '預計', '准', '炫耀', '證', '認為', '假設', '避免', '宣佈', '想要', '聊', '提猜', '提', '聽說', '揭曉', '想起', '討說', '管', '設想', '廣播', '確認', '公認', '回顧', '慶祝', '商量', '猜', '聯想', '鑒定', '證明', '禁止', '提到', '談', '抱怨', '看看', '調研', '介紹', '問', '提起', '爆料', '公佈', '允許', '以為', '精准', '安排', '樂見', '公示', '賭約', '自嘲', '告訴', '呼籲', '想到', '考慮', '形容', '發誓', '呼', '見', '查看', '預定', '盛贊', '申卡', '公告', '示範', '知詢', '報道', '說明', '看清楚', '預防', '聽', '研究', '警惕', '承諾', '看出', '提醒', '探討', '發佈', '傳聞', '查', '識別', '發現', '檢測', '估值', '要', '想']
# =======================
# DE : ['得', '的', '地', '之']
# =======================
# VHC : ['開', '暫停', '冷卻', '平衡', '加快', '豐富', '減少', '規模化', '增強', '斷', '還原', '公開', '陷', '可憐', '破', '繁榮', '感動', '恢復', '壞', '機構化', '傷', '停', '優化', '愁死', '煩', '智能化', '滿足', '增加', '告破', '現代化', '下來', '擴張', '降低', '縮小', '國際化', '辛苦', '穩定', '團結', '震驚', '淡化', '熱', '強化', '愁壞', '增 ', '增長', '凍', '變動', '產生', '肥', '結束', '溫暖', '麻煩', '普及']
# =======================
# Ng : ['內', '時', '後', '中', '之內', '以外', '以下', '起', '之前', '之外', '前', '以後', '間', '初', '下', '之下', '上', '為止', '而言', '之中', '來', '之上', '左右', '底', '裡', '外', '般', '之後', '以上', '之間', '以來']
# =======================
# VK : ['覺得', '堅持', '信', '害怕', '需要', '感覺到', '確定', '感謝', '奇怪', '同意', '指望', '遺憾', '欲', '盼', '忘', '回憶', '理解', '恨', '希望', '願意', '肯定', '不忘', '感覺', '需', '不滿', '注意', '放心', '擔心', '感受', '明白', '願', '曲解', '知', '懂', '想見', '依賴', '瞭解', '面臨', '懷疑', '流傳', '知道', '所謂', '討厭', '懂得', '意味', '介意', '抱歉', '期待', '意外', '意想不到', '有利於', '覺', '怕', '遇', '忘記', '小心', '恐', '喜歡', '顯示']
# =======================
# Ncd : ['底部', '內', '當中', '那裡', '那邊', '中部', '中', '方', '哪裡', '北', '以下', '東西部', '西部', '東方', '畔', '旁邊', '間', '下', '末端', '前沿', '中間', '上', '東部', '西', '上面', '兩旁', '哪兒', '外', '裡', '一帶', '邊', '哪下', '這裡', '外面', '裡面', '東', '對面', '哪', '上方']
# =======================
# A : ['超級', '高度', '頭號', '同一', '大幅度', '一般', '中', '地下', '必備', '二手', '上上', '單', '優質', '非', '長途', '基礎', '歐式', '真正', '共同', '獨家', '新興', '總', '野生', '多餘', '碧藍', '雙', '同等', '常務', '小本', '後置', '獨門', '寶有', '前置', '超', '額外', '新一代', '重磅', '中西', '麻辣', '獨角', '主', '業餘', '原', '最佳', '眾', '彩色', '綜合', '國產', '現行', '現役', '火紅', '基層', '乒乓', '唯一']
# =======================
# V_2 : ['有']
# =======================
# VL : ['不惜', '使得', '肯', '愛', '習慣', '敢', '令', '能', '愛好', '導致', '後悔', '甘願', '趨於', '喜好', '致', '開始', '持續', '故意', '讓', '便利', '使', '用來']
# =======================
# T : ['矣', '哦', '的', '了', '咯', '啊', '麼', '去', '哪', '嘛', '呢', '來', '吧', '嗎', '啦']
# =======================
# VI : ['著稱', '專用', '取勝', '傾心', '驚艷']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['據說', '外傳', '結果', '想不到', '那麼', '據聞', '那', '反過來']
# =======================
# VF : ['拒', '催', '叫', '推選', '停止', '圖', '鼓勵', '勸住', '勸說', '判', '告誡', '逼', '繼續', '請', '助', '擬', '試試', '準備', '邀', '試', '要求', '率領', '拒絕', '打算', '止住', '策劃', '申請', '帶領']
# =======================
# Da : ['光', '共', '才', '只', '不下', '正好', '足足', '僅', '幾乎', '唯獨', '幾近', '約', '近', '最多', '將近']
# =======================
# PARENTHESISCATEGORY : ['（', '《', '(', '」', '「', '》', '）']
# =======================
# Nv : ['營銷', '兼職', '代理', '開發', '配置', '問', '旅遊', '崩潰', '管理', '翻譯', '買單', '絕殺', '燃燒', '創業', '研究', '生產', '錄制', '護髮', '工作', '判罰', '灌籃', '射擊', '度假', '訴訟', '輔助', '航海', '分銷', '體驗', '推薦', '批發', '增發', '供電', '抗戰', '遊樂', '組合', '登山', '解救', '銷售', '思考', '惡搞', '關聯', '經歷', '防治', '疊加', '回歸', '私募']
# =======================
# PERIODCATEGORY : ['·', '。']
# =======================
# VAC : ['集合', '動', '推進', '蒸發', '移動', '上演']
# =======================
# Dfb : ['一點', '極了', '些']
# =======================
# Cab : ['等', '等等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['以上', '幾', '半', '多']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 
        'ETCCATEGORY', 'EXCLAMATIONCATEGORY', 'PARENTHESISCATEGORY',
        'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY',
        'SEMICOLONCATEGORY', 'SPCHANGECATEGORY', 'WHITESPACE'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
tmp = np.sqrt(sum(np.array([1, 2, 0, 0]) ** 2))
tmp
# Out:
# 2.23606797749979

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    similarity = np.dot(bow1, bow2) / ( np.sqrt(sum(bow1 ** 2)) * np.sqrt(sum(bow2 ** 2)) )
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
# group_vectors = {news_class: [] for news_class in all_news_class}
# for index, pairs in sorted(train_title_cuts.items()):
#     vector = get_bow_vector_with_selection(pairs, word2index)
#     news_class = train_classes[index]
#     group_vectors[news_class].append(vector)

# group_mean_vector = {}
# for news_class, vectors in group_vectors.items():
#     group_mean_vector[news_class] = np.mean(vectors, axis=0)
# group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0., 0., 0., ..., 0., 0., 0.])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)
classification
# Out:
# {'體育': [1800,
#   1802,
#   1803,
#   1804,
#   1805,
#   1806,
#   1807,
#   1808,
#   1813,
#   1814,
#   1816,
#   1817,
#   1818,
#   1819,
#   1820,
#   1821,
#   1822,
#   1823,
#   1824,
#   1826,
#   1828,
#   1830,
#   1831,
#   1832,
#   1833,
#   1835,
#   1836,
#   1840,
#   1842,
#   1843,
#   1844,
#   1847,
#   1851,
#   1852,
#   1853,
#   1854,
#   1855,
#   1857,
#   1858,
#   1859,
#   1862,
#   1863,
#   1864,
#   1866,
#   1867,
#   1868,
#   1869,
#   1871,
#   1872,
#   1873,
#   1876,
#   1877,
#   1878,
#   1879,
#   1880,
#   1881,
#   1883,
#   1884,
#   1886,
#   1887,
#   1888,
#   1890,
#   1891,
#   1892,
#   1894,
#   1899,
#   1906,
#   1907,
#   1921,
#   1935,
#   1977,
#   1979,
#   2034,
#   2048,
#   2058,
#   2081,
#   2109,
#   2116,
#   2120,
#   2129,
#   2130,
#   2135,
#   2154,
#   2172,
#   2178,
#   2192,
#   2196,
#   2199,
#   2211,
#   2233,
#   2246,
#   2265,
#   2277,
#   2304,
#   2308,
#   2309,
#   2310,
#   2320,
#   2323,
#   2332,
#   2354,
#   2370],
#  '財經': [1811,
#   1815,
#   1825,
#   1827,
#   1838,
#   1841,
#   1865,
#   1874,
#   1900,
#   1901,
#   1902,
#   1904,
#   1905,
#   1908,
#   1909,
#   1910,
#   1911,
#   1912,
#   1913,
#   1914,
#   1915,
#   1916,
#   1917,
#   1920,
#   1924,
#   1925,
#   1929,
#   1930,
#   1931,
#   1933,
#   1934,
#   1936,
#   1937,
#   1940,
#   1941,
#   1942,
#   1943,
#   1945,
#   1947,
#   1948,
#   1949,
#   1950,
#   1953,
#   1954,
#   1955,
#   1957,
#   1960,
#   1964,
#   1965,
#   1966,
#   1967,
#   1968,
#   1969,
#   1970,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1978,
#   1981,
#   1983,
#   1984,
#   1985,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1997,
#   1998,
#   1999,
#   2000,
#   2008,
#   2009,
#   2012,
#   2014,
#   2016,
#   2024,
#   2026,
#   2040,
#   2042,
#   2045,
#   2054,
#   2061,
#   2065,
#   2075,
#   2077,
#   2078,
#   2082,
#   2098,
#   2102,
#   2114,
#   2128,
#   2138,
#   2141,
#   2146,
#   2157,
#   2162,
#   2200,
#   2214,
#   2221,
#   2224,
#   2243,
#   2253,
#   2259,
#   2268,
#   2283,
#   2338,
#   2358,
#   2367,
#   2385,
#   2395],
#  '科技': [1812,
#   1829,
#   1834,
#   1837,
#   1839,
#   1845,
#   1846,
#   1849,
#   1860,
#   1870,
#   1875,
#   1889,
#   1893,
#   1903,
#   1918,
#   1922,
#   1923,
#   1926,
#   1928,
#   1938,
#   1951,
#   1952,
#   1956,
#   1961,
#   1962,
#   1963,
#   2001,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2010,
#   2015,
#   2017,
#   2018,
#   2019,
#   2020,
#   2021,
#   2022,
#   2023,
#   2025,
#   2027,
#   2028,
#   2031,
#   2032,
#   2033,
#   2035,
#   2036,
#   2037,
#   2038,
#   2039,
#   2041,
#   2044,
#   2046,
#   2047,
#   2049,
#   2050,
#   2051,
#   2052,
#   2053,
#   2055,
#   2056,
#   2059,
#   2060,
#   2062,
#   2064,
#   2067,
#   2069,
#   2070,
#   2072,
#   2074,
#   2076,
#   2079,
#   2080,
#   2083,
#   2084,
#   2088,
#   2089,
#   2090,
#   2091,
#   2094,
#   2095,
#   2096,
#   2097,
#   2099,
#   2111,
#   2118,
#   2124,
#   2151,
#   2160,
#   2164,
#   2168,
#   2198,
#   2201,
#   2207,
#   2208,
#   2210,
#   2218,
#   2228,
#   2229,
#   2239,
#   2245,
#   2254,
#   2258,
#   2267,
#   2287,
#   2290,
#   2291,
#   2293,
#   2313,
#   2325,
#   2330,
#   2391,
#   2394],
#  '旅遊': [1809,
#   1848,
#   1850,
#   1919,
#   1939,
#   1944,
#   1946,
#   1971,
#   1980,
#   1986,
#   1995,
#   1996,
#   2030,
#   2085,
#   2092,
#   2103,
#   2104,
#   2105,
#   2106,
#   2107,
#   2108,
#   2110,
#   2112,
#   2113,
#   2115,
#   2117,
#   2119,
#   2122,
#   2123,
#   2125,
#   2126,
#   2127,
#   2132,
#   2133,
#   2134,
#   2136,
#   2139,
#   2140,
#   2142,
#   2143,
#   2144,
#   2145,
#   2147,
#   2148,
#   2152,
#   2155,
#   2156,
#   2158,
#   2161,
#   2163,
#   2165,
#   2167,
#   2169,
#   2171,
#   2173,
#   2175,
#   2176,
#   2177,
#   2180,
#   2182,
#   2183,
#   2184,
#   2186,
#   2187,
#   2188,
#   2189,
#   2190,
#   2191,
#   2193,
#   2197,
#   2209,
#   2212,
#   2216,
#   2220,
#   2223,
#   2231,
#   2236,
#   2242,
#   2247,
#   2270,
#   2299,
#   2306,
#   2359],
#  '農業': [1882,
#   1898,
#   1932,
#   1982,
#   2011,
#   2013,
#   2063,
#   2066,
#   2068,
#   2073,
#   2101,
#   2121,
#   2166,
#   2181,
#   2195,
#   2202,
#   2203,
#   2204,
#   2205,
#   2206,
#   2213,
#   2215,
#   2217,
#   2219,
#   2222,
#   2225,
#   2226,
#   2230,
#   2232,
#   2234,
#   2238,
#   2240,
#   2241,
#   2244,
#   2248,
#   2249,
#   2250,
#   2251,
#   2252,
#   2255,
#   2256,
#   2257,
#   2260,
#   2261,
#   2262,
#   2263,
#   2264,
#   2266,
#   2269,
#   2271,
#   2272,
#   2273,
#   2274,
#   2275,
#   2276,
#   2278,
#   2279,
#   2280,
#   2281,
#   2282,
#   2284,
#   2285,
#   2286,
#   2288,
#   2289,
#   2292,
#   2294,
#   2295,
#   2296,
#   2297,
#   2298,
#   2328,
#   2352,
#   2379,
#   2392],
#  '遊戲': [1801,
#   1810,
#   1856,
#   1861,
#   1885,
#   1895,
#   1896,
#   1897,
#   1927,
#   1958,
#   1959,
#   1994,
#   2002,
#   2029,
#   2043,
#   2057,
#   2071,
#   2086,
#   2087,
#   2093,
#   2100,
#   2131,
#   2137,
#   2149,
#   2150,
#   2153,
#   2159,
#   2170,
#   2174,
#   2179,
#   2185,
#   2194,
#   2227,
#   2235,
#   2237,
#   2300,
#   2301,
#   2302,
#   2303,
#   2305,
#   2307,
#   2311,
#   2312,
#   2314,
#   2315,
#   2316,
#   2317,
#   2318,
#   2319,
#   2321,
#   2322,
#   2324,
#   2326,
#   2327,
#   2329,
#   2331,
#   2333,
#   2334,
#   2335,
#   2336,
#   2337,
#   2339,
#   2340,
#   2341,
#   2342,
#   2343,
#   2344,
#   2345,
#   2346,
#   2347,
#   2348,
#   2349,
#   2350,
#   2351,
#   2353,
#   2355,
#   2356,
#   2357,
#   2360,
#   2361,
#   2362,
#   2363,
#   2364,
#   2365,
#   2366,
#   2368,
#   2369,
#   2371,
#   2372,
#   2373,
#   2374,
#   2375,
#   2376,
#   2377,
#   2378,
#   2380,
#   2381,
#   2382,
#   2383,
#   2384,
#   2386,
#   2387,
#   2388,
#   2389,
#   2390,
#   2393,
#   2396,
#   2397,
#   2398,
#   2399]}

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 66, '旅遊': 12, '遊戲': 9, '財經': 6, '農業': 5, '科技': 4})
# predict 財經 :  Counter({'財經': 66, '科技': 19, '農業': 9, '體育': 8, '旅遊': 8, '遊戲': 5})
# predict 科技 :  Counter({'科技': 60, '農業': 16, '體育': 13, '財經': 13, '旅遊': 8, '遊戲': 5})
# predict 旅遊 :  Counter({'旅遊': 55, '農業': 11, '財經': 9, '體育': 3, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 56, '科技': 6, '旅遊': 5, '遊戲': 4, '體育': 2, '財經': 2})
# predict 遊戲 :  Counter({'遊戲': 75, '旅遊': 12, '體育': 8, '科技': 8, '財經': 4, '農業': 3})

# %%
for group, ids in classification.items():
    
    corrects = [test_titles[id] for id in ids if group == test_classes[id]]
    falses = [test_titles[id] for id in ids if group != test_classes[id]]
    print(f'predict {group}: falses: {falses}')
    print(f'accuracy: {len(corrects) / (len(corrects) + len(falses))}')
# Out:
# predict 體育: falses: ['國產軟件+智慧城市第一龍頭，漲停突破再創新高，能否一飛沖天', '月薪12000怎麼理財？', '深圳文博會大力提升專業化辦展水平', '美天然氣NaturalGas中短線交易策略及技術走勢MT4解盤五月三日', '阿里18Q1：收入增長61%，成本上漲110%，均創歷史新高', '什麼藥能同時在桃、李、柑橘、荔枝樹上殺蟎、蚧、夜蛾和卵？', '貴陽大數據、人工智能等前沿技術發展，先行優勢已經突顯', '8場高端對話 50余場專業論壇邀你同台論道', '聊聊shopify', '36氪首發｜「立刻出行」完成B輪融資，螞蟻金服領投', '山東徹底火了！濟南五一納客122.72萬人，泰山一天接待8萬人……', '外媒稱海南將成中國對外開放新窗口：繁榮程度或超越香港', '震撼：30張世界級照片，你可能連一張也沒見過', '平陸小三亞，坡底糧宿灘', 'APEC懷柔會址最佳觀覽點建成', '乾貨｜持中國大陸護照在新加坡如何申請入台證', '巍巍太行 世外桃源-薄壁、雙底、上雲台-南太行自駕路書（1）', '喜大普奔！歷時3年，寧波又將添一地標性建築！竣工時間在今年的', '雲南茶花甲天下，艷甲滇雲在大理了', '世界第一偉人是誰？', '世界第一偉人是誰？', '中國最美森林，號稱「東方亞馬遜」，就在雲南，你知道是哪裡嗎？', '大數據+農業 山間「野果」走出「逆襲路」', '2018/5/6今日全國生豬報價', '福州金魚亮相成都農博會 今年計劃舉辦30場巡展', '一夜之間十佘畝西瓜全被開瓢，農戶氣得生病', '玉米怎麼控旺？', '大神帶玩，連紅', '韓國3大網紅終極對決COS《守望先鋒》D.va誰更美', '世乒賽決賽第二盤，樊振東3:0取勝削球手菲魯斯，怎麼評價本場比賽？', 'SUP三戰全勝領跑B組 日本冠軍一勝難求', 'QGhappy最後的倔強！使用奪冠陣容連輸三局後將要面臨保級', 'YTG的路西法怎麼又成替補了？', 'Dnf武器怎麼上13？', '卡莎第一次在MSI敗北，新人解說頻爆金句成為亮點！', 'DNF：歷年天空套外觀一覽，國服十週年會送哪一套？']
# accuracy: 0.6470588235294118
# predict 財經: falses: ['科比他的一生之敵只有一個人，不是詹姆斯，那會是誰？', '小克里琴科都不是富里的對手，英國狂人卻揚言將其KO出局', '還是李曉霞會說話：啥也不說了東京拿下，今天男隊也拿下齊活了', '如何評價TT和卡戴珊餐廳用餐引起克城球迷恐慌的事情？', '周日中超盤口分析', '就今天的情況來看，到底是低估了騎士隊，還是高估了猛龍隊呢？', '劉偉解說乒乓球比賽的水平如何？', '劉偉解說乒乓球比賽的水平如何？', '聯想物流如何擁抱新零售', '店大欺客，我們都是被互聯網企業欺負的普通人', '傳統PC互聯網頁正遭到邊緣化，PC真的「已死」嗎？', '傳魅族將裁員千人，裁員的原因是什麼？', '一個浙江省保險代理公司，如何利用互聯網開展業務？', '創業者如何寫出一份打動投資人並能首次融資3000萬的商業計劃書？', '2018年最新靠譜網賺項目！日賺300元', '區塊鏈+新零售：是新經濟風口，或是簡單聯姻，網友：新時代必然', '粉絲每天穩定增長產品資訊獲得更多曝光，如何利用免費流量？', '想註冊滴滴，駕齡不滿3年怎麼辦？', '如何刪除手機里沒用的文件？', 'Top500發起人將領銜ASC18超算與AI國際論壇', '這家銀行夠狠！半年內使用兩次螞蟻借唄京東白條 別想申房貸車貸', '關於ODE幣經典技術成保障，可能成為幣市新指向標的幾點分析', 'AI時代，物流企業如何「順勢而為」實現智慧升級？', '好事流芳千古；求下句？', '拼多多為什麼是新型社交電商開創者？', '「Very OK」雷布斯，「力挺蘋果」巴菲特｜本週熱門人物盤點', '你如何看待個人信息嚴重洩露的問題，這就是所謂的大數據嗎？', '祖國的綠水青山處處是美景', '歷時三年，昆明文廟即將開門迎客！', '行程是十天，東京進出，中途要去京都和奈良然後回東京，如何買交通卡呢？', '為什麼有人說桂林是下一個鳳凰古城？', '這次夏威夷真的很火，真相令人是喜是憂呢？！', '川藏線旅遊包車費用是如何算的？', '書上說，地球上大量的雨水蓄滿了火山口，形成海洋。雨水是淡水，海水為什麼是咸的？', '溪流與河流的差別是什麼？', '對於蒜農來說，什麼時候賣蒜合適？', '想開水果店，如何找貨源比較好？', '鄉村教師如何增加自己的收入 看網友們都是如何做的', '這種植物，在路邊是綠化，上餐桌是美食，進醫院就是中藥材！', '將貧困戶融入市場主體之中 恩施特色產業帶動62.5萬人脫貧', '冬瓜子如何育苗？', '陽東大溝吉灶下村舊貌換新顏', '陝西特色小鎮咋建 防止盲目造鎮和地產化發展', '如何預防小麥後期出現倒伏？', '如何評價首個以職業選手命名的比賽uzi杯？', '如何評價KPL EDG.M戰隊的職業選手無痕？', '如何評價KPL EDG.M戰隊的職業選手無痕？', '安格的國服孫尚香，日常五殺都是常規操作，簡直秀的飛起！', '如何玩好《陰陽師》？']
# accuracy: 0.5739130434782609
# predict 科技: falses: ['為什麼明明詹姆斯最後體力不支，但是投那個絕殺球的時候，還能跳那麼高？', '什麼造就了今年的季後賽隆多', '足球比賽中守門員什麼情況下可以用手，什麼時候又不能？', '有人說游泳比跑步的減肥效果更好，是真的嗎？為什麼？', '斯諾克世錦賽結束後，小丁世界排名會掉到多少位？', '郜林：一方狀態信心比我們強 盼亞冠發揮真正的水平', '皇馬會擱置歐冠，全力狙擊巴薩的不敗奪冠嗎？齊達內公開表態', '馬刺可以拿卡哇伊和雄鹿換字母哥嗎？', '足球比賽中守門員什麼情況下可以用手，什麼時候又不能？', '2018乒乓球世錦賽為什麼沒有張繼科？', '他是菲爾普斯此生最大的冠軍威脅，他的百萬豪車更讓「飛魚」膽寒', '為什麼10年總決賽巔峰詹姆斯韋德波斯三巨頭輸給司機的小牛？', '離開新疆的李秋平，下賽季會到哪個球隊執教？', '二十萬用來投資期貨好不好？', '看看這些吸血蟲的微信，就知道空貸套路深了！', '通過並購把公司做大，這個華人的影響力比馬雲、李嘉誠還大', '怎樣做白酒？', '為什麼美聯儲不屬於美國政府？', '用手機怎麼賺錢？', '「5.6全球資訊」烏克蘭出現首個全村擁有數字貨幣的村莊', '2018中國有哪些著名的營銷咨詢公司？', '「聚焦絲博會 展示新形象」「韓城製造」系列產品將亮相絲博會', '蘋果市值又漲了這麼多 庫克暗自發笑 暴漲原因竟然是他的出現', '為什麼中國的動畫電影做不到美國的水平？', '孫正義沒有當過亞洲首富嗎，為什麼？', '瑞郎幣FRCoin：金融王國走出的新虛擬貨幣，規避風險的財富搖籃', '上饒有什麼好玩的地方？', '日本茨城機場附近有什麼能玩的地方麼？', '國家為什麼不允許用紅磚建房？', '河北省保定市易縣和定興，將來哪裡發展比較好？', '南京小吃街叫什麼？', '農家大門上可以用五脊六獸嗎？', '《雍正王朝》四阿哥胤禛和十三阿哥胤祥，辦差路過江夏鎮為什麼必須下馬步行通過？', '大理的喜洲古鎮有什麼好吃好玩的？', '如何能有效，快速的提高我們的專業知識（畜牧類）？', '錢的妙用——有錢能使鬼推磨】接上', '玉米種子什麼牌子的好？', '互聯網+農業 村網通有哪些優勢？跟其它類似平台有什麼區別？', '杜清潔：從木工到致富領頭羊', '怎樣能提高春雨小麥收割機的速度？', '俄羅斯的農作物和蔬菜真的不使用農藥化肥嗎？', '大麗花的花朵謝了，用剪掉嗎？', '大興安嶺墾區做強「五彩產業」', '紅豆杉能插栽嗎？', '什麼品種的玉米種最抗倒伏？', '定點養殖中蜂效益好嗎？', '廣西賀州石斛花開，各色石斛五顏六色，奼紫嫣紅', '獼猴桃對光照的需求是這樣的！40%~45為宜', '打擊私屠濫宰 確保肉品安全', '什麼品種的玉米種最抗倒伏？', '《荒野行動》的鼠標靈敏度要怎麼調才最好？', 'ns破解方法如果被公開，對正版玩家有什麼影響？', '主播小智長相很可怕嗎？', '關於奧特曼的好玩的手機遊戲有什麼推薦嗎？', '騷男情商到底有多高？卡特拿全隊最高人頭，仍謙虛表示沒發揮好']
# accuracy: 0.5217391304347826
# predict 旅遊: falses: ['「熱點新聞」+24！塔圖姆的正負值再次追平隊史季後賽新秀單場', '2017/18賽季英超爭四，利物浦vs切爾西最後的決戰', '為何CBA籃球運動員孫悅的妻子陳露被稱為「CBA第一夫人」？', '一位老股民的血淚史：中國股市永遠也看不厭的一篇股市文章！', '詳解簡單精准的抄底技巧，真正搞懂的寥寥無幾', '上汽財務：這家主營車貸的公司2017年利潤總額69億 ', '天量貨幣存量形成解析——看好你的資本，放下你的槓桿', '賺得盆滿鉢滿不知足，這國趁機抬價，中國一出手，500億化為烏有', '不只是水晶杯\xa0捷克主賓國文化周帶你領略不一樣的捷克風情', '最近的股市，我們不妨可以學學這個西方的分析技術！', '恆邦潤滑油「來福士」商標通過國家商標局認定！', '「孟非的小面」關門，相比其他餐飲差在哪裡？', '如果有時光機 你最想去和誰見面？馬雲想見的是他們', '全球區塊鏈之歐洲篇：英國領先，避稅天堂馬耳他欲建區塊鏈島', '這個自行車和共享單車王國，如何設計「秒殺」擁堵的新型個人交通工具？', '故鄉嵐縣，四月的農家小院早晨', '雞群里的三代同堂——腺肌胃炎', '貝店宣佈「一縣一品」助農計劃，一年將打造100個特色產品產業帶', '中國每年進口1.3億噸糧食 可你知道這些糧食怎麼消耗掉的嗎', '近幾年莊稼病蟲害增加，適當休耕既可解決地力枯竭的問題，又可減少病蟲害的發生，你怎麼看？', '三亞獨有「牛奶蓮霧」上市 本地消費者「一果難求」', '從一家15年不倒的水果店，看農業經營的5大啓示', '昨天7毛，今天才賣4毛，蒜薹一天一個收購價，蒜農仍能坦然面對', '小記——老張的故事', '仙居：文化牆扮靚美麗鄉村', '嫁接不求人，只需這「神器」，一壓一按一次搞定，成活率極高', '來之不易的勝利！這支戰隊使出渾身解數終於拿下賽季第二勝！', 'LOL：驚喜最後一天！花木蘭電玩馬南瓜頭瞭解一下？']
# accuracy: 0.6626506024096386
# predict 農業: falses: ['曼聯穆帥愛將自稱值5000萬鎊？英媒：一半都達不到，不配效力曼聯', '凱爾特人3-0了，但為什麼賽前ESPN21位專家有18位都預測76人晉級？', '美國工薪家庭基本支出和改善性支出都有哪些？', '上海的經濟要想超越東京，需要多久？', '如下圖，電腦開不起來了，重新ghost恢復備份的系統後啓動依舊藍屏，怎麼辦？', '如下圖，電腦開不起來了，重新ghost恢復備份的系統後啓動依舊藍屏，怎麼辦？', '農村電商，如何做好電商公共服務？', '歷史上有哪些恐怖的發明？', '互聯網巨頭品牌競爭拼「潮」勁，蘇寧小獅子賣萌領潮流', '你認為現有4G網，網速好不好？', '初夏花開日，人生初見時，五月賞這幾種花木正當時', '安徽徐集鎮以綠色生態為理念 建成紫荊花特色小鎮帶動鄉村發展', '雲南省5月6日11時至5月7日11時部分風景區天氣預報', '全球最危險的公路，只有一路狂飆才能活下去，當地政府都不敢限速', '賣的快斷貨的「戶外神器」，折疊後小到離譜，出行0負擔更開心', '夢幻西游洗完野豬又洗蝙蝠 最後須彌煉妖居然有驚喜', '在拳皇97中，為什麼有些人物使用瑪麗的bug夾不需要在角落里？', '《皇室戰爭》5月新卡將出！注意，有張法術牌又要削弱', '什麼樣的顯卡能低配吃雞？']
# accuracy: 0.7466666666666667
# predict 遊戲: falses: ['從個人競技狀態來看，三個階段的詹姆斯，哪個最強？', '6日體育精選：「人事觀察」奧運冠軍吳敏霞當選上海團市委副書記，這個崗位有多位體育明星', '如果劉國梁出國執教你是支持還是反對？', '當濃眉哥轟下33分18板時，你才會發現隆多的厲害之處', 'LCX潮：最帥籃球鞋 OFF-WHITE x Nike Hyperdunk HD2017 OW評測', '亞洲杯，國足抽了個好簽？', '巴西足球隊歷史最強後衛有哪些？', '霍福德定勝負，凱爾特人客勝76人彩帶搶鏡，史蒂文斯太強了', '「滾雪球」今天你戴「周大生」了嗎？', '用卡or玩卡！信用卡你最看重的是什麼……', '巴菲特：中國經濟找到了秘訣，就像我們幾個世紀前一樣', '正新雞排加盟費多少｜整店輸出模式｜一站式服務', '霍金給人類留下了幾個預言？', '哪個共享汽車app收費比較便宜？', '作為一個5s 16G用戶，iphone8plus和iphone7plus買哪個比較好？', '第二屆世界智能大會世界智能科技展邀你體驗「黑科技」', '華為榮耀7C和錘子3，選哪款比較好？', '「失控」的預言，如果你讀過它，也許你就不會錯過比特幣', '哪個語種國家的人更喜歡iOS？答案有點意外', '華為mate10和vivoX21指紋版選哪個比較好？', '微信史上最囧挑戰15關圖文攻略 史上最囧挑戰15關五星好評答案', '微信史上最囧挑戰12關圖文攻略 史上最囧挑戰12關找不同的貓答案', '廣西北海和三亞哪個好玩？費用哪個高？', '當您有錢了以後最想跟誰出去旅行？', '情侶退房，保潔阿姨進門清掃時傻眼了，保潔阿姨：不由得哭了！', '說到出國旅遊，人們第一個想到的是哪幾個國家？', '蘇州上方山森林動物世界鸚鵡籠捨為何鬧鼠患？', '廣西北海和三亞哪個好玩？費用哪個高？', '扶溝在鄭州哪個地方？', '巴釐島旅遊街拍 你是否見到過', '你喜歡自由行嗎？為什麼？', '「太行之魂」，卻因連環交通費，遭遊客吐槽「史上最強坑」！', '世界那麼大，獨愛龐各莊小西瓜', '蒜薹收穫季，愁壞了莊稼人，本應喜迎豐收卻為了四處求人收蒜薹', '它長相似榴蓮，個頭大過榴蓮，你知道是什麼水果嗎？']
# accuracy: 0.6818181818181818
